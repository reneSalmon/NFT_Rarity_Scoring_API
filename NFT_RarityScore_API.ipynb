# %%
import requests

response = requests.get("http://randomfox.ca/floof")
print(response.status_code)
# Out:
# 200

# %%
response.text
# Out:
# '{"image":"https:\\/\\/randomfox.ca\\/images\\/24.jpg","link":"https:\\/\\/randomfox.ca\\/?i=24"}'

# %%
fox = response.json()
fox
# Out:
# {'image': 'https://randomfox.ca/images/24.jpg',
#  'link': 'https://randomfox.ca/?i=24'}

# %%
img_link = fox['image']
img_link
# Out:
# 'https://randomfox.ca/images/24.jpg'

# %%
fox['image']
# Out:
# 'https://randomfox.ca/images/24.jpg'

# %%
from PIL import Image
import io

response = requests.get(img_link)
in_memory_file = io.BytesIO(response.content)
image = Image.open(in_memory_file)
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=564x846 at 0x10FCC1F70>

# %%
image.size
# Out:
# (564, 846)

# %%
image.thumbnail((400, 400))
image.save('image_thumbnail.jpg')

print(image.size)
# Out:
# (267, 400)

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=267x400 at 0x10FCC1F70>

# %%
#TimoAPI
response = requests.get("https://service.cryptotrunks.co/token/1322")
print(response.status_code)
# Out:
# 200

# %%
response.text
# Out:
# '{"attributes":[{"trait_type":"Edition","value":"Genesis"},{"trait_type":"Sky","value":"Beach and Sea with Clouds"},{"trait_type":"Age","value":"Ancient"},{"trait_type":"Type","value":"Golden Birch"},{"trait_type":"Element","value":"Cow"}],"backgrounds":["Beach and Sea with Clouds"],"elements":["Cow"],"external_url":"https://cryptotrunks.co/individual-trunk-page.html?token=1322","id":1322,"image":"https://service.cryptotrunks.co/image.png?token=1322","name":"CryptoTrunk #1322","number":1322,"tree":"Tree \\u2014 Golden Birch \\u2014 Ancient"}\n'

# %%
timo_NFT = response.json()
timo_NFT
# Out:
# {'attributes': [{'trait_type': 'Edition', 'value': 'Genesis'},
#   {'trait_type': 'Sky', 'value': 'Beach and Sea with Clouds'},
#   {'trait_type': 'Age', 'value': 'Ancient'},
#   {'trait_type': 'Type', 'value': 'Golden Birch'},
#   {'trait_type': 'Element', 'value': 'Cow'}],
#  'backgrounds': ['Beach and Sea with Clouds'],
#  'elements': ['Cow'],
#  'external_url': 'https://cryptotrunks.co/individual-trunk-page.html?token=1322',
#  'id': 1322,
#  'image': 'https://service.cryptotrunks.co/image.png?token=1322',
#  'name': 'CryptoTrunk #1322',
#  'number': 1322,
#  'tree': 'Tree — Golden Birch — Ancient'}

# %%
NFT_image_link = timo_NFT['image']
NFT_image_link
# Out:
# 'https://service.cryptotrunks.co/image.png?token=1322'

# %%
from PIL import Image
import io

response = requests.get(NFT_image_link)
in_memory_file = io.BytesIO(response.content)
image = Image.open(in_memory_file)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=500x500 at 0x10FCE6520>

# %%
timo_NFT
# Out:
# {'attributes': [{'trait_type': 'Edition', 'value': 'Genesis'},
#   {'trait_type': 'Sky', 'value': 'Beach and Sea with Clouds'},
#   {'trait_type': 'Age', 'value': 'Ancient'},
#   {'trait_type': 'Type', 'value': 'Golden Birch'},
#   {'trait_type': 'Element', 'value': 'Cow'}],
#  'backgrounds': ['Beach and Sea with Clouds'],
#  'elements': ['Cow'],
#  'external_url': 'https://cryptotrunks.co/individual-trunk-page.html?token=1322',
#  'id': 1322,
#  'image': 'https://service.cryptotrunks.co/image.png?token=1322',
#  'name': 'CryptoTrunk #1322',
#  'number': 1322,
#  'tree': 'Tree — Golden Birch — Ancient'}

# %%
#Create list with NFT traits
List_of_trait_types = timo_NFT['attributes']
List_of_trait_types
# Out:
# [{'trait_type': 'Edition', 'value': 'Genesis'},
#  {'trait_type': 'Sky', 'value': 'Beach and Sea with Clouds'},
#  {'trait_type': 'Age', 'value': 'Ancient'},
#  {'trait_type': 'Type', 'value': 'Golden Birch'},
#  {'trait_type': 'Element', 'value': 'Cow'}]

# %%
#Create list that counts all traits
List_of_trait_types[0]
# Out:
# {'trait_type': 'Edition', 'value': 'Genesis'}

# %%
print(List_of_trait_types[0]['trait_type'])
print(List_of_trait_types[0]['value'])
# Out:
# Edition
# Genesis

# %%
#Count all trait

# %%
#GOAL 
import pandas as pd
data = {'NFT_ID': [1322, 454, 1, 11], 
        'Edition': ['Genesis', 'Genesis', 'Genesis', 'Genesis'], 
        'AGE':['Acient', 'Acient', 'Acient', 'Acient' ],
        'Element':['Monncat Lying', 'Cow', 'Monncat Lying', 'Cow'],
        'SKY':['Deep Space' , 'Beach and Sea', 'Beach and Sea','Deep Space'],
        'Type':['Maple Treeho', 'Golden Birch', 'Maple Treeho', 'Golden Birch']}

pd.DataFrame.from_dict(data)
# Out:
#    NFT_ID  Edition     AGE        Element            SKY          Type
# 0    1322  Genesis  Acient  Monncat Lying     Deep Space  Maple Treeho
# 1     454  Genesis  Acient            Cow  Beach and Sea  Golden Birch
# 2       1  Genesis  Acient  Monncat Lying  Beach and Sea  Maple Treeho
# 3      11  Genesis  Acient            Cow     Deep Space  Golden Birch

# %%
#TimoAPI
response = requests.get("https://api.opensea.io/api/v1/assets?collection=cryptotrunks&format=json&limit=50&offset=50&order_direction=desc")
print(response.status_code)
# Out:
# 200

# %%
response.text
# Out:
# '{"assets":[{"id":37037838,"token_id":"210","num_sales":0,"background_color":null,"image_url":"https://lh3.googleusercontent.com/rcyl4LohJGUpGdXcaUyevEtEvm9-lceiH3JrVYPdbu2W_K8o6ylLKE6Cr2XKNK59AauIpweOGdePK-cAR9mSoWh9KxspgYMQ1SbuKw","image_preview_url":"https://lh3.googleusercontent.com/rcyl4LohJGUpGdXcaUyevEtEvm9-lceiH3JrVYPdbu2W_K8o6ylLKE6Cr2XKNK59AauIpweOGdePK-cAR9mSoWh9KxspgYMQ1SbuKw=s250","image_thumbnail_url":"https://lh3.googleusercontent.com/rcyl4LohJGUpGdXcaUyevEtEvm9-lceiH3JrVYPdbu2W_K8o6ylLKE6Cr2XKNK59AauIpweOGdePK-cAR9mSoWh9KxspgYMQ1SbuKw=s128","image_original_url":"https://service.cryptotrunks.co/image.png?token=210","animation_url":null,"animation_original_url":null,"name":"CryptoTrunk #210","description":null,"external_link":"https://cryptotrunks.co/individual-trunk-page.html?token=210","asset_contract":{"address":"0x375ea781c49eafedde07afe6196f885761f166ae","asset_contract_type":"non-fungible","created_date":"2021-05-16T02:08:19.098730","name":"CryptoTrunks","nft_vers
# ...

# %%
Crypto_trunks_50_json = response.json()
Crypto_trunks_50_json
# Out:
# {'assets': [{'id': 37037838,
#    'token_id': '210',
#    'num_sales': 0,
#    'background_color': None,
#    'image_url': 'https://lh3.googleusercontent.com/rcyl4LohJGUpGdXcaUyevEtEvm9-lceiH3JrVYPdbu2W_K8o6ylLKE6Cr2XKNK59AauIpweOGdePK-cAR9mSoWh9KxspgYMQ1SbuKw',
#    'image_preview_url': 'https://lh3.googleusercontent.com/rcyl4LohJGUpGdXcaUyevEtEvm9-lceiH3JrVYPdbu2W_K8o6ylLKE6Cr2XKNK59AauIpweOGdePK-cAR9mSoWh9KxspgYMQ1SbuKw=s250',
#    'image_thumbnail_url': 'https://lh3.googleusercontent.com/rcyl4LohJGUpGdXcaUyevEtEvm9-lceiH3JrVYPdbu2W_K8o6ylLKE6Cr2XKNK59AauIpweOGdePK-cAR9mSoWh9KxspgYMQ1SbuKw=s128',
#    'image_original_url': 'https://service.cryptotrunks.co/image.png?token=210',
#    'animation_url': None,
#    'animation_original_url': None,
#    'name': 'CryptoTrunk #210',
#    'description': None,
#    'external_link': 'https://cryptotrunks.co/individual-trunk-page.html?token=210',
#    'asset_contract': {'address': '0x375ea781c49eafedde07afe6196f885761f166ae',
# ...

# %%
len(Crypto_trunks_50_json['assets'])
# Out:
# 50

# %%
List_of_50_NFTs = Crypto_trunks_50_json['assets']

# %%
List_of_50_NFTs_Only_Id1 = List_of_50_NFTs[0]['token_id']
List_of_50_NFTs_Only_Id1
# Out:
# '210'

# %%
NFT_IDs =[List_of_50_NFTs[NFT]['token_id'] for NFT in range(len(Crypto_trunks_50_json['assets']))]
NFT_IDs
# Out:
# ['210',
#  '733',
#  '1256',
#  '279',
#  '802',
#  '1325',
#  '348',
#  '871',
#  '1394',
#  '417',
#  '940',
#  '1463',
#  '486',
#  '1009',
#  '32',
#  '555',
#  '1078',
#  '101',
#  '624',
#  '1147',
#  '170',
#  '693',
#  '1216',
#  '239',
#  '762',
#  '1285',
#  '308',
#  '831',
#  '1354',
#  '377',
#  '900',
#  '1423',
#  '446',
#  '969',
#  '1492',
#  '515',
#  '1038',
#  '61',
#  '584',
#  '1107',
#  '130',
#  '653',
#  '1176',
#  '199',
#  '722',
#  '1245',
#  '268',
#  '791',
#  '1314',
#  '337']

# %%
List_of_50_NFTs_Only_Traits_of_NFT1 = List_of_50_NFTs[0]['traits']
List_of_50_NFTs_Only_Traits_of_NFT1
# Out:
# [{'trait_type': 'Type',
#   'value': 'Burning Ash',
#   'display_type': None,
#   'max_value': None,
#   'trait_count': 13,
#   'order': None},
#  {'trait_type': 'Age',
#   'value': 'Elder',
#   'display_type': None,
#   'max_value': None,
#   'trait_count': 2758,
#   'order': None},
#  {'trait_type': 'Edition',
#   'value': 'Genesis',
#   'display_type': None,
#   'max_value': None,
#   'trait_count': 1501,
#   'order': None},
#  {'trait_type': 'Element',
#   'value': 'Among Us – Orange',
#   'display_type': None,
#   'max_value': None,
#   'trait_count': 11,
#   'order': None},
#  {'trait_type': 'Sky',
#   'value': 'Underwater City and Road',
#   'display_type': None,
#   'max_value': None,
#   'trait_count': 21,
#   'order': None}]

# %%
List_of_50_NFTs_Only_Traits_of_NFT1[1]['trait_type']
# Out:
# 'Age'

# %%
List_of_50_NFTs_Only_Traits_of_NFT = [List_of_50_NFTs[NFT]['traits'] for NFT in range(len(Crypto_trunks_50_json['assets']))]
List_of_50_NFTs_Only_Traits_of_NFT
# Out:
# [[{'trait_type': 'Type',
#    'value': 'Burning Ash',
#    'display_type': None,
#    'max_value': None,
#    'trait_count': 13,
#    'order': None},
#   {'trait_type': 'Age',
#    'value': 'Elder',
#    'display_type': None,
#    'max_value': None,
#    'trait_count': 2758,
#    'order': None},
#   {'trait_type': 'Edition',
#    'value': 'Genesis',
#    'display_type': None,
#    'max_value': None,
#    'trait_count': 1501,
#    'order': None},
#   {'trait_type': 'Element',
#    'value': 'Among Us – Orange',
#    'display_type': None,
#    'max_value': None,
#    'trait_count': 11,
#    'order': None},
#   {'trait_type': 'Sky',
#    'value': 'Underwater City and Road',
#    'display_type': None,
#    'max_value': None,
#    'trait_count': 21,
#    'order': None}],
#  [{'trait_type': 'Age',
#    'value': 'Ancient',
#    'display_type': None,
#    'max_value': None,
#    'trait_count': 893,
#    'order': None},
#   {'trait_type': 'Background',
#    'value': 'Urban – Town',
# ...

# %%
# Now I have a list of 50 NFT. Which includes all trait_types and the amount of them. 
List_of_Traits_in_one_NFT = List_of_50_NFTs_Only_Traits_of_NFT[0]
List_of_Traits_in_one_NFT
# Out:
# [{'trait_type': 'Type',
#   'value': 'Burning Ash',
#   'display_type': None,
#   'max_value': None,
#   'trait_count': 13,
#   'order': None},
#  {'trait_type': 'Age',
#   'value': 'Elder',
#   'display_type': None,
#   'max_value': None,
#   'trait_count': 2758,
#   'order': None},
#  {'trait_type': 'Edition',
#   'value': 'Genesis',
#   'display_type': None,
#   'max_value': None,
#   'trait_count': 1501,
#   'order': None},
#  {'trait_type': 'Element',
#   'value': 'Among Us – Orange',
#   'display_type': None,
#   'max_value': None,
#   'trait_count': 11,
#   'order': None},
#  {'trait_type': 'Sky',
#   'value': 'Underwater City and Road',
#   'display_type': None,
#   'max_value': None,
#   'trait_count': 21,
#   'order': None}]

# %%
# List of only all trait_type for each NFT

# %%
Trait_types_for_NFTs = [List_of_50_NFTs_Only_Traits_of_NFT[NFT][TRAIT_TYPE]['trait_type'] List_of_50_NFTs_Only_Traits_of_NFT[NFT] for NFT in range(len(List_of_50_NFTs_Only_Traits_of_NFT))]

# %%
Trait_types_for_NFTs
# Out:
# [[{'trait_type': 'Type',
#    'value': 'Burning Ash',
#    'display_type': None,
#    'max_value': None,
#    'trait_count': 13,
#    'order': None},
#   {'trait_type': 'Age',
#    'value': 'Elder',
#    'display_type': None,
#    'max_value': None,
#    'trait_count': 2758,
#    'order': None},
#   {'trait_type': 'Edition',
#    'value': 'Genesis',
#    'display_type': None,
#    'max_value': None,
#    'trait_count': 1501,
#    'order': None},
#   {'trait_type': 'Element',
#    'value': 'Among Us – Orange',
#    'display_type': None,
#    'max_value': None,
#    'trait_count': 11,
#    'order': None},
#   {'trait_type': 'Sky',
#    'value': 'Underwater City and Road',
#    'display_type': None,
#    'max_value': None,
#    'trait_count': 21,
#    'order': None}],
#  [{'trait_type': 'Age',
#    'value': 'Ancient',
#    'display_type': None,
#    'max_value': None,
#    'trait_count': 893,
#    'order': None},
#   {'trait_type': 'Background',
#    'value': 'Urban – Town',
# ...

# %%
#List all trait_type_values for each NFT

# %%
Trait_types_for_NFTs[1][4]['trait_type']
# Out:
# 'Type'

# %%
len(Trait_types_for_NFTs[0])
# Out:
# 5

# %%
Traits_in_NFT_01 = [
    Trait_types_for_NFTs[0][TYPE]['trait_type']
    for TYPE in range(len(Trait_types_for_NFTs[0]))] 
Traits_in_NFT_01
# Out:
# ['Type', 'Age', 'Edition', 'Element', 'Sky']

# %%
len(Traits_in_NFT_01)
# Out:
# 5

# %%
while TYPE == len(Traits_in_NFT_01)

# %%
Traits_in_all_NFT = [Trait_types_for_NFTs[NFT][TYPE]['trait_type'] 
                     for NFT in range(len(List_of_50_NFTs_Only_Traits_of_NFT)) 
                     for TYPE in range(len(Trait_types_for_NFTs[NFT])) ]

# %%
Traits_in_all_NFT
# Out:
# ['Type',
#  'Age',
#  'Edition',
#  'Element',
#  'Sky',
#  'Age',
#  'Background',
#  'Background',
#  'Edition',
#  'Type',
#  'Element',
#  'Sky',
#  'Background',
#  'Age',
#  'Edition',
#  'Sky',
#  'Element',
#  'Background',
#  'Type',
#  'Age',
#  'Background',
#  'Edition',
#  'Type',
#  'Sky',
#  'Background',
#  'Age',
#  'Edition',
#  'Element',
#  'Sky',
#  'Background',
#  'Type',
#  'Background',
#  'Element',
#  'Background',
#  'Element',
#  'Age',
#  'Edition',
#  'Background',
#  'Type',
#  'Sky',
#  'Type',
#  'Age',
#  'Edition',
#  'Sky',
#  'Element',
#  'Element',
#  'Age',
#  'Edition',
#  'Sky',
#  'Type',
#  'Type',
#  'Element',
#  'Sky',
#  'Edition',
#  'Age',
#  'Sky',
#  'Type',
#  'Age',
#  'Edition',
#  'Element',
#  'Background',
#  'Background',
#  'Edition',
#  'Age',
#  'Sky',
#  'Type',
#  'Type',
#  'Element',
#  'Background',
#  'Background',
#  'Edition',
#  'Sky',
#  'Age',
#  'Background',
#  'Background',
#  'Background',
#  'Sky',
# ...

# %%
All_traits_type = set(Traits_in_all_NFT)
print(All_traits_type)
print(len(All_traits_type))
# Out:
# {'Age', 'Edition', 'Background', 'Type', 'Animated', 'Element', 'property', 'Sky'}
# 8

# %%
import collections
counter=collections.Counter(Traits_in_all_NFT)
counter
# Out:
# Counter({'Type': 50,
#          'Age': 49,
#          'Edition': 50,
#          'Element': 34,
#          'Sky': 50,
#          'Background': 65,
#          'property': 2,
#          'Animated': 1})

# %%
import pandas as pd
data = {'NFT_ID': [1322, 454, 1, 11],
        'Edition': ['Genesis', 'Genesis', 'Genesis', 'Genesis'], 
        'AGE':['Acient', 'Acient', 'Acient', 'Acient' ],
        'Element':['Monncat Lying', 'Cow', 'Monncat Lying', 'Cow'],
        'SKY':['Deep Space' , 'Beach and Sea', 'Beach and Sea','Deep Space'],
        'Animated':['Maple Treeho', 'Golden Birch', 'Maple Treeho', 'Golden Birch'],
        'property':['Maple Treeho', 'Golden Birch', 'Maple Treeho', 'Golden Birch'],
        'Background':['Maple Treeho', 'Golden Birch', 'Maple Treeho', 'Golden Birch'],
        'Type':['Maple Treeho', 'Golden Birch', 'Maple Treeho', 'Golden Birch'],
           }

pd.DataFrame.from_dict(data)
# Out:
#    NFT_ID  Edition     AGE        Element            SKY      Animated  \
# 0    1322  Genesis  Acient  Monncat Lying     Deep Space  Maple Treeho
# 1     454  Genesis  Acient            Cow  Beach and Sea  Golden Birch
# 2       1  Genesis  Acient  Monncat Lying  Beach and Sea  Maple Treeho
# 3      11  Genesis  Acient            Cow     Deep Space  Golden Birch
#
#        property    Background          Type
# 0  Maple Treeho  Maple Treeho  Maple Treeho
# 1  Golden Birch  Golden Birch  Golden Birch
# 2  Maple Treeho  Maple Treeho  Maple Treeho
# 3  Golden Birch  Golden Birch  Golden Birch

# %%
#Collect for each trait the value
Edition_value_in_NFT_01 = [
    Trait_types_for_NFTs[0][TYPE]['value']
    for TYPE in range(len(Trait_types_for_NFTs[0]))
    if  Trait_types_for_NFTs[0][TYPE]['trait_type'] == 'Edition'] 
Edition_value_in_NFT_01
# Out:
# ['Genesis']

# %%
Trait_types_for_NFTs[0][3]['value']
# Out:
# 'Among Us – Orange'

# %%
#Collect values for all NFTS with the trait Edition
Edition_value_in_all_NFT = [
    Trait_types_for_NFTs[NFT][TYPE]['value']
    if  Trait_types_for_NFTs[NFT][TYPE]['trait_type'] == 'Edition'
    else 'no value'
    for NFT in range(len(List_of_50_NFTs_Only_Traits_of_NFT))
    for TYPE in range(len(Trait_types_for_NFTs[NFT]))]
Edition_value_in_all_NFT
# Out:
# ['no value',
#  'no value',
#  'Genesis',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Genesis',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Genesis',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Genesis',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Genesis',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Genesis',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Genesis',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Genesis',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Genesis',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Genesis',
#  'no value',
#  'no value',
#  'no value',
#  'Genesis',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
# ...

# %%
#Collect values for all NFTS with the trait AGE
Age_value_in_all_NFT = [
    Trait_types_for_NFTs[NFT][TYPE]['value']
    if  Trait_types_for_NFTs[NFT][TYPE]['trait_type'] == 'Age'
    else 'no value'
    for NFT in range(len(List_of_50_NFTs_Only_Traits_of_NFT))
    for TYPE in range(len(Trait_types_for_NFTs[NFT]))]
Age_value_in_all_NFT
# Out:
# ['no value',
#  'Elder',
#  'no value',
#  'no value',
#  'no value',
#  'Ancient',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Elder',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Young',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Young',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Young',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Elder',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Elder',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Sapling',
#  'no value',
#  'no value',
#  'Elder',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Adult',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
# ...

# %%
#Collect values for all NFTS with the trait Element
Element_value_in_all_NFT = [
    Trait_types_for_NFTs[NFT][TYPE]['value']
    if  Trait_types_for_NFTs[NFT][TYPE]['trait_type'] == 'Element'
    else 'no value'
    for NFT in range(len(List_of_50_NFTs_Only_Traits_of_NFT))
    for TYPE in range(len(Trait_types_for_NFTs[NFT]))]
Element_value_in_all_NFT
# Out:
# ['no value',
#  'no value',
#  'no value',
#  'Among Us – Orange',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Dead Bear',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Among Us – Red',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Shooting Star',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Ghost',
#  'no value',
#  'Golden Birds in Flight',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Golden Hearts',
#  'Golden Gravestone',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Golden Monkey',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Among Us – Red',
#  'no value',
#  'no value',
# ...

# %%
#Collect values for all NFTS with the trait SKY
Sky_value_in_all_NFT = [
    Trait_types_for_NFTs[NFT][TYPE]['value']
    if  Trait_types_for_NFTs[NFT][TYPE]['trait_type'] == 'Sky'
    else 'no value'
    for NFT in range(len(List_of_50_NFTs_Only_Traits_of_NFT))
    for TYPE in range(len(Trait_types_for_NFTs[NFT]))]
Sky_value_in_all_NFT
# Out:
# ['no value',
#  'no value',
#  'no value',
#  'no value',
#  'Underwater City and Road',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Volcano',
#  'no value',
#  'no value',
#  'no value',
#  'Space',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Night',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Clear Blue',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Night',
#  'no value',
#  'no value',
#  'no value',
#  'Volcano with Town and Savanah Grass',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Beach and Desert with Oasis',
#  'no value',
#  'no value',
#  'no value',
#  'Abstract',
#  'no value',
#  'no value',
#  'Cloudy Sky',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
# ...

# %%
#Collect values for all NFTS with the trait Animated
Animated_value_in_all_NFT = [
    Trait_types_for_NFTs[NFT][TYPE]['value']
    if  Trait_types_for_NFTs[NFT][TYPE]['trait_type'] == 'Animated'
    else 'no value'
    for NFT in range(len(List_of_50_NFTs_Only_Traits_of_NFT))
    for TYPE in range(len(Trait_types_for_NFTs[NFT]))]
Animated_value_in_all_NFT
# Out:
# ['no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
# ...

# %%
#Collect values for all NFTS with the trait Property
Property_value_in_all_NFT = [
    Trait_types_for_NFTs[NFT][TYPE]['value']
    if  Trait_types_for_NFTs[NFT][TYPE]['trait_type'] == 'property'
    else 'no value'
    for NFT in range(len(List_of_50_NFTs_Only_Traits_of_NFT))
    for TYPE in range(len(Trait_types_for_NFTs[NFT]))]
Property_value_in_all_NFT
# Out:
# ['no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
# ...

# %%
#Collect values for all NFTS with the trait Background
Background_value_in_all_NFT = [
    Trait_types_for_NFTs[NFT][TYPE]['value']
    if  Trait_types_for_NFTs[NFT][TYPE]['trait_type'] == 'Background'
    else 'no value'
    for NFT in range(len(List_of_50_NFTs_Only_Traits_of_NFT))
    for TYPE in range(len(Trait_types_for_NFTs[NFT]))]
Background_value_in_all_NFT
# Out:
# ['no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Urban – Town',
#  'Grass – Soft',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Hills – Rolling',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Clouds',
#  'no value',
#  'no value',
#  'Grass – Soft',
#  'no value',
#  'no value',
#  'no value',
#  'Forest – Leafy',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Clouds',
#  'no value',
#  'Mountains – Highlands',
#  'no value',
#  'Forest – Leafy',
#  'no value',
#  'no value',
#  'no value',
#  'Clouds',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Urban – Skyline',
#  'Grass – Meadow',
#  'no value',
# ...

# %%
#Collect values for all NFTS with the trait Type
Type_value_in_all_NFT = [
    Trait_types_for_NFTs[NFT][TYPE]['value']
    if  Trait_types_for_NFTs[NFT][TYPE]['trait_type'] == 'Type'
    else 'no value'
    for NFT in range(len(List_of_50_NFTs_Only_Traits_of_NFT))
    for TYPE in range(len(Trait_types_for_NFTs[NFT]))]
Type_value_in_all_NFT
# Out:
# ['Burning Ash',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Golden Birch',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Spruce Treehouse',
#  'no value',
#  'no value',
#  'no value',
#  'Oak Treehouse',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Ash Treehouse',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Spruce Treehouse',
#  'no value',
#  'Maple Treehouse',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Rainbow Spruce',
#  'Cherry Empress',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'Cherry Empress',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
#  'no value',
# ...

# %%
import pandas as pd
data = {#'NFT_ID': NFT_IDs,
        'Edition': Edition_value_in_all_NFT, 
        'AGE':Age_value_in_all_NFT,
        'Element':Element_value_in_all_NFT,
        'SKY':Sky_value_in_all_NFT,
        'Animated':Animated_value_in_all_NFT,
        'property':Property_value_in_all_NFT,
        'Background':Background_value_in_all_NFT,
        'Type': Type_value_in_all_NFT
           }

pd.DataFrame.from_dict(data)
# Out:
#       Edition       AGE            Element                       SKY  \
# 0    no value  no value           no value                  no value
# 1       Elder     Elder           no value                  no value
# 2    no value  no value           no value                  no value
# 3    no value  no value  Among Us – Orange                  no value
# 4    no value  no value           no value  Underwater City and Road
# ..        ...       ...                ...                       ...
# 296  no value  no value           no value                  no value
# 297  no value  no value           no value                  no value
# 298  no value  no value           no value                  no value
# 299     Adult     Adult           no value                  no value
# 300  no value  no value           no value                  no value
#
#      Animated  property           Background             Type
# 0    no value  no value             no value      Burning Ash
# ...

# %%
print(len(NFT_IDs))
# Out:
# 50

# %%
print(len(Edition_value_in_all_NFT))
print(len(Age_value_in_all_NFT))
# Out:
# 301
# 301
