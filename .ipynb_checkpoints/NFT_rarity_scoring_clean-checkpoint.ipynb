# %% [markdown]
# # Product vision and goals

# %%
#Vision
#An API that enables user to identify the most rar NFTs

# %%
#Goal 01: Create a trait_rarity_score

import pandas as pd
data = {'NFT_ID': [1322, 454, 1, 11],
        'Trait_ID': [1322, 454, 1, 11],
        'Type': ['Genesis', 'Genesis', 'none', 'Genesis'], 
        'Value': [0.5, 0.1, 0.5, 0.4],
        'Type_count': [123, 2, 0, 32], 
        'Type_rarity_percentage': [0.6, 0.6, 0.4, 0.4],
        'Trait_Rarity_Score': [16.6, 8.6, 8.6, 12.5],
        'Ranking_position': [16, 8, 8, 12],
       }

pd.DataFrame.from_dict(data)
# Out:
#    NFT_ID  Trait_ID     Type  Value  Type_count  Type_rarity_percentage  \
# 0    1322      1322  Genesis    0.5         123                     0.6
# 1     454       454  Genesis    0.1           2                     0.6
# 2       1         1     none    0.5           0                     0.4
# 3      11        11  Genesis    0.4          32                     0.4
#
#    Trait_Rarity_Score  Ranking_position
# 0                16.6                16
# 1                 8.6                 8
# 2                 8.6                 8
# 3                12.5                12

# %%
#Goal 02: Create a NFT_rarity_score 

import pandas as pd
data = {'NFT_ID': [1322, 454, 1, 11],
        'NFT_Rarity_Score': [16.6, 8.6, 8.6, 12.5],
        'NFT_Ranking_Position': [1 , 3, 3, 2]
        }

pd.DataFrame.from_dict(data)
# Out:
#    NFT_ID  NFT_Rarity_Score  NFT_Ranking_Position
# 0    1322              16.6                     1
# 1     454               8.6                     3
# 2       1               8.6                     3
# 3      11              12.5                     2

# %% [markdown]
# #  Imported moduls

# %%
#Import moduls
import requests
import collections
import pandas as pd
from itertools import islice
import json

# %% [markdown]
# # Get Data via API

# %%
#Call OpenSea API to get CryptoTrunks Data
response = requests.get("https://api.opensea.io/api/v1/assets?collection=cryptotrunks&format=json&limit=50&offset=50&order_direction=desc")
print(response.status_code)
# Out:
# 200

# %%
#Save first 50 CryptoTrunks Data as JSON
Crypto_trunks_50_json = response.json()
Crypto_trunks_50_json
# Out:
# {'assets': [{'id': 37037838,
#    'token_id': '210',
#    'num_sales': 0,
#    'background_color': None,
#    'image_url': 'https://lh3.googleusercontent.com/rcyl4LohJGUpGdXcaUyevEtEvm9-lceiH3JrVYPdbu2W_K8o6ylLKE6Cr2XKNK59AauIpweOGdePK-cAR9mSoWh9KxspgYMQ1SbuKw',
#    'image_preview_url': 'https://lh3.googleusercontent.com/rcyl4LohJGUpGdXcaUyevEtEvm9-lceiH3JrVYPdbu2W_K8o6ylLKE6Cr2XKNK59AauIpweOGdePK-cAR9mSoWh9KxspgYMQ1SbuKw=s250',
#    'image_thumbnail_url': 'https://lh3.googleusercontent.com/rcyl4LohJGUpGdXcaUyevEtEvm9-lceiH3JrVYPdbu2W_K8o6ylLKE6Cr2XKNK59AauIpweOGdePK-cAR9mSoWh9KxspgYMQ1SbuKw=s128',
#    'image_original_url': 'https://service.cryptotrunks.co/image.png?token=210',
#    'animation_url': None,
#    'animation_original_url': None,
#    'name': 'CryptoTrunk #210',
#    'description': None,
#    'external_link': 'https://cryptotrunks.co/individual-trunk-page.html?token=210',
#    'asset_contract': {'address': '0x375ea781c49eafedde07afe6196f885761f166ae',
#     'asset_contract_type': 'non-fungible',
#     'created_date': '2021-05-16T02:08:19.098730',
#     'name': 'CryptoTrunks',
#     'nft_version': '3.0',
#     'opensea_version': None,
#     'owner': 601,
#     'schema_name': 'ERC721',
#     'symbol': 'CT',
#     'total_supply': '0',
#     'description': 'A generative series of NFTs created using oracles.',
#     'external_link': 'https://cryptotrunks.co',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'default_to_fiat': False,
#     'dev_buyer_fee_basis_points': 0,
#     'dev_seller_fee_basis_points': 100,
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': 0,
#     'opensea_seller_fee_basis_points': 250,
#     'buyer_fee_basis_points': 0,
#     'seller_fee_basis_points': 350,
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051'},
#    'permalink': 'https://opensea.io/assets/0x375ea781c49eafedde07afe6196f885761f166ae/210',
#    'collection': {'banner_image_url': 'https://lh3.googleusercontent.com/qLspBme9CU_VvkZpkQMXXjRFTy1JEMQJ_knfxxeQqTwYlSTqFC-NlCBAWuMm8dFNQdbKfuj4MlB19XD-OPp81x1Mo0S9M44YoWuW2w=s2500',
#     'chat_url': None,
#     'created_date': '2021-05-16T02:34:27.616469',
#     'default_to_fiat': False,
#     'description': 'A generative series of NFTs created using oracles.',
#     'dev_buyer_fee_basis_points': '0',
#     'dev_seller_fee_basis_points': '100',
#     'discord_url': 'https://discord.gg/yv8trsNXbJ',
#     'display_data': {'card_display_style': 'cover'},
#     'external_url': 'https://cryptotrunks.co',
#     'featured': False,
#     'featured_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'hidden': False,
#     'safelist_request_status': 'verified',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'is_subject_to_whitelist': False,
#     'large_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'medium_username': None,
#     'name': 'CryptoTrunks',
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': '0',
#     'opensea_seller_fee_basis_points': '250',
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'require_email': False,
#     'short_description': None,
#     'slug': 'cryptotrunks',
#     'telegram_url': None,
#     'twitter_username': 'thecryptotrunks',
#     'instagram_username': None,
#     'wiki_url': None},
#    'decimals': 0,
#    'token_metadata': 'https://service.cryptotrunks.co/token/210',
#    'owner': {'user': {'username': None},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/15.png',
#     'address': '0x1dc301854bfecb4ba03eb417579585c2b8ea12c1',
#     'config': ''},
#    'sell_orders': None,
#    'creator': {'user': {'username': 'TrunkDev'},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/7.png',
#     'address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'config': ''},
#    'traits': [{'trait_type': 'Type',
#      'value': 'Burning Ash',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 13,
#      'order': None},
#     {'trait_type': 'Age',
#      'value': 'Elder',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 2758,
#      'order': None},
#     {'trait_type': 'Edition',
#      'value': 'Genesis',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 1501,
#      'order': None},
#     {'trait_type': 'Element',
#      'value': 'Among Us – Orange',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 11,
#      'order': None},
#     {'trait_type': 'Sky',
#      'value': 'Underwater City and Road',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 21,
#      'order': None}],
#    'last_sale': None,
#    'top_bid': None,
#    'listing_date': None,
#    'is_presale': False,
#    'transfer_fee_payment_token': None,
#    'transfer_fee': None},
#   {'id': 37037836,
#    'token_id': '733',
#    'num_sales': 0,
#    'background_color': None,
#    'image_url': 'https://lh3.googleusercontent.com/2Ob0m2GsK-y_zLBvx3XsHLdeY1QCcA3DSWscbyGyn3WslvNLZFad9p7eEpTU9UgS-67vSagX6bRRoC8deXeGljg5BXIl_ZxL8tW1',
#    'image_preview_url': 'https://lh3.googleusercontent.com/2Ob0m2GsK-y_zLBvx3XsHLdeY1QCcA3DSWscbyGyn3WslvNLZFad9p7eEpTU9UgS-67vSagX6bRRoC8deXeGljg5BXIl_ZxL8tW1=s250',
#    'image_thumbnail_url': 'https://lh3.googleusercontent.com/2Ob0m2GsK-y_zLBvx3XsHLdeY1QCcA3DSWscbyGyn3WslvNLZFad9p7eEpTU9UgS-67vSagX6bRRoC8deXeGljg5BXIl_ZxL8tW1=s128',
#    'image_original_url': 'https://service.cryptotrunks.co/image.png?token=733',
#    'animation_url': None,
#    'animation_original_url': None,
#    'name': 'CryptoTrunk #733',
#    'description': None,
#    'external_link': 'https://cryptotrunks.co/individual-trunk-page.html?token=733',
#    'asset_contract': {'address': '0x375ea781c49eafedde07afe6196f885761f166ae',
#     'asset_contract_type': 'non-fungible',
#     'created_date': '2021-05-16T02:08:19.098730',
#     'name': 'CryptoTrunks',
#     'nft_version': '3.0',
#     'opensea_version': None,
#     'owner': 601,
#     'schema_name': 'ERC721',
#     'symbol': 'CT',
#     'total_supply': '0',
#     'description': 'A generative series of NFTs created using oracles.',
#     'external_link': 'https://cryptotrunks.co',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'default_to_fiat': False,
#     'dev_buyer_fee_basis_points': 0,
#     'dev_seller_fee_basis_points': 100,
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': 0,
#     'opensea_seller_fee_basis_points': 250,
#     'buyer_fee_basis_points': 0,
#     'seller_fee_basis_points': 350,
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051'},
#    'permalink': 'https://opensea.io/assets/0x375ea781c49eafedde07afe6196f885761f166ae/733',
#    'collection': {'banner_image_url': 'https://lh3.googleusercontent.com/qLspBme9CU_VvkZpkQMXXjRFTy1JEMQJ_knfxxeQqTwYlSTqFC-NlCBAWuMm8dFNQdbKfuj4MlB19XD-OPp81x1Mo0S9M44YoWuW2w=s2500',
#     'chat_url': None,
#     'created_date': '2021-05-16T02:34:27.616469',
#     'default_to_fiat': False,
#     'description': 'A generative series of NFTs created using oracles.',
#     'dev_buyer_fee_basis_points': '0',
#     'dev_seller_fee_basis_points': '100',
#     'discord_url': 'https://discord.gg/yv8trsNXbJ',
#     'display_data': {'card_display_style': 'cover'},
#     'external_url': 'https://cryptotrunks.co',
#     'featured': False,
#     'featured_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'hidden': False,
#     'safelist_request_status': 'verified',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'is_subject_to_whitelist': False,
#     'large_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'medium_username': None,
#     'name': 'CryptoTrunks',
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': '0',
#     'opensea_seller_fee_basis_points': '250',
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'require_email': False,
#     'short_description': None,
#     'slug': 'cryptotrunks',
#     'telegram_url': None,
#     'twitter_username': 'thecryptotrunks',
#     'instagram_username': None,
#     'wiki_url': None},
#    'decimals': 0,
#    'token_metadata': 'https://service.cryptotrunks.co/token/733',
#    'owner': {'user': {'username': None},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/15.png',
#     'address': '0x1dc301854bfecb4ba03eb417579585c2b8ea12c1',
#     'config': ''},
#    'sell_orders': None,
#    'creator': {'user': {'username': 'TrunkDev'},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/7.png',
#     'address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'config': ''},
#    'traits': [{'trait_type': 'Age',
#      'value': 'Ancient',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 893,
#      'order': None},
#     {'trait_type': 'Background',
#      'value': 'Urban – Town',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 1526,
#      'order': None},
#     {'trait_type': 'Background',
#      'value': 'Grass – Soft',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 88,
#      'order': None},
#     {'trait_type': 'Edition',
#      'value': 'Genesis',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 1501,
#      'order': None},
#     {'trait_type': 'Type',
#      'value': 'Golden Birch',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 58,
#      'order': None},
#     {'trait_type': 'Element',
#      'value': 'Dead Bear',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 52,
#      'order': None},
#     {'trait_type': 'Sky',
#      'value': 'Volcano',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 50,
#      'order': None}],
#    'last_sale': None,
#    'top_bid': None,
#    'listing_date': None,
#    'is_presale': False,
#    'transfer_fee_payment_token': None,
#    'transfer_fee': None},
#   {'id': 37037834,
#    'token_id': '1256',
#    'num_sales': 0,
#    'background_color': None,
#    'image_url': 'https://lh3.googleusercontent.com/Bvz7MFSwkbq63yecwsSyZWJnPpEJggIvkmYMdpeAF_HZdww9pWNPMG9zQ_zAk6IV6iQPpZW-g3ylqNk_FqtomxNx7BL6RYZbKdhZkQ',
#    'image_preview_url': 'https://lh3.googleusercontent.com/Bvz7MFSwkbq63yecwsSyZWJnPpEJggIvkmYMdpeAF_HZdww9pWNPMG9zQ_zAk6IV6iQPpZW-g3ylqNk_FqtomxNx7BL6RYZbKdhZkQ=s250',
#    'image_thumbnail_url': 'https://lh3.googleusercontent.com/Bvz7MFSwkbq63yecwsSyZWJnPpEJggIvkmYMdpeAF_HZdww9pWNPMG9zQ_zAk6IV6iQPpZW-g3ylqNk_FqtomxNx7BL6RYZbKdhZkQ=s128',
#    'image_original_url': 'https://service.cryptotrunks.co/image.png?token=1256',
#    'animation_url': None,
#    'animation_original_url': None,
#    'name': 'CryptoTrunk #1256',
#    'description': None,
#    'external_link': 'https://cryptotrunks.co/individual-trunk-page.html?token=1256',
#    'asset_contract': {'address': '0x375ea781c49eafedde07afe6196f885761f166ae',
#     'asset_contract_type': 'non-fungible',
#     'created_date': '2021-05-16T02:08:19.098730',
#     'name': 'CryptoTrunks',
#     'nft_version': '3.0',
#     'opensea_version': None,
#     'owner': 601,
#     'schema_name': 'ERC721',
#     'symbol': 'CT',
#     'total_supply': '0',
#     'description': 'A generative series of NFTs created using oracles.',
#     'external_link': 'https://cryptotrunks.co',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'default_to_fiat': False,
#     'dev_buyer_fee_basis_points': 0,
#     'dev_seller_fee_basis_points': 100,
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': 0,
#     'opensea_seller_fee_basis_points': 250,
#     'buyer_fee_basis_points': 0,
#     'seller_fee_basis_points': 350,
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051'},
#    'permalink': 'https://opensea.io/assets/0x375ea781c49eafedde07afe6196f885761f166ae/1256',
#    'collection': {'banner_image_url': 'https://lh3.googleusercontent.com/qLspBme9CU_VvkZpkQMXXjRFTy1JEMQJ_knfxxeQqTwYlSTqFC-NlCBAWuMm8dFNQdbKfuj4MlB19XD-OPp81x1Mo0S9M44YoWuW2w=s2500',
#     'chat_url': None,
#     'created_date': '2021-05-16T02:34:27.616469',
#     'default_to_fiat': False,
#     'description': 'A generative series of NFTs created using oracles.',
#     'dev_buyer_fee_basis_points': '0',
#     'dev_seller_fee_basis_points': '100',
#     'discord_url': 'https://discord.gg/yv8trsNXbJ',
#     'display_data': {'card_display_style': 'cover'},
#     'external_url': 'https://cryptotrunks.co',
#     'featured': False,
#     'featured_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'hidden': False,
#     'safelist_request_status': 'verified',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'is_subject_to_whitelist': False,
#     'large_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'medium_username': None,
#     'name': 'CryptoTrunks',
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': '0',
#     'opensea_seller_fee_basis_points': '250',
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'require_email': False,
#     'short_description': None,
#     'slug': 'cryptotrunks',
#     'telegram_url': None,
#     'twitter_username': 'thecryptotrunks',
#     'instagram_username': None,
#     'wiki_url': None},
#    'decimals': 0,
#    'token_metadata': 'https://service.cryptotrunks.co/token/1256',
#    'owner': {'user': {'username': None},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/15.png',
#     'address': '0x1dc301854bfecb4ba03eb417579585c2b8ea12c1',
#     'config': ''},
#    'sell_orders': None,
#    'creator': {'user': {'username': 'TrunkDev'},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/7.png',
#     'address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'config': ''},
#    'traits': [{'trait_type': 'Background',
#      'value': 'Hills – Rolling',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 100,
#      'order': None},
#     {'trait_type': 'Age',
#      'value': 'Elder',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 2758,
#      'order': None},
#     {'trait_type': 'Edition',
#      'value': 'Genesis',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 1501,
#      'order': None},
#     {'trait_type': 'Sky',
#      'value': 'Space',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 51,
#      'order': None},
#     {'trait_type': 'Element',
#      'value': 'Among Us – Red',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 10,
#      'order': None},
#     {'trait_type': 'Background',
#      'value': 'Clouds',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 100,
#      'order': None},
#     {'trait_type': 'Type',
#      'value': 'Spruce Treehouse',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 47,
#      'order': None}],
#    'last_sale': None,
#    'top_bid': None,
#    'listing_date': None,
#    'is_presale': False,
#    'transfer_fee_payment_token': None,
#    'transfer_fee': None},
#   {'id': 37037833,
#    'token_id': '279',
#    'num_sales': 0,
#    'background_color': None,
#    'image_url': 'https://lh3.googleusercontent.com/3ilvDn4p9giBUzboJ2UDolaQ7dQA2fiag4s71tZGnyJRP9mlRY2YFREjY3tbK5dOA5JZoDcSVuGSFbLx1ofyH1v7f7pabNXrLrFxv6M',
#    'image_preview_url': 'https://lh3.googleusercontent.com/3ilvDn4p9giBUzboJ2UDolaQ7dQA2fiag4s71tZGnyJRP9mlRY2YFREjY3tbK5dOA5JZoDcSVuGSFbLx1ofyH1v7f7pabNXrLrFxv6M=s250',
#    'image_thumbnail_url': 'https://lh3.googleusercontent.com/3ilvDn4p9giBUzboJ2UDolaQ7dQA2fiag4s71tZGnyJRP9mlRY2YFREjY3tbK5dOA5JZoDcSVuGSFbLx1ofyH1v7f7pabNXrLrFxv6M=s128',
#    'image_original_url': 'https://service.cryptotrunks.co/image.png?token=279',
#    'animation_url': None,
#    'animation_original_url': None,
#    'name': 'CryptoTrunk #279',
#    'description': None,
#    'external_link': 'https://cryptotrunks.co/individual-trunk-page.html?token=279',
#    'asset_contract': {'address': '0x375ea781c49eafedde07afe6196f885761f166ae',
#     'asset_contract_type': 'non-fungible',
#     'created_date': '2021-05-16T02:08:19.098730',
#     'name': 'CryptoTrunks',
#     'nft_version': '3.0',
#     'opensea_version': None,
#     'owner': 601,
#     'schema_name': 'ERC721',
#     'symbol': 'CT',
#     'total_supply': '0',
#     'description': 'A generative series of NFTs created using oracles.',
#     'external_link': 'https://cryptotrunks.co',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'default_to_fiat': False,
#     'dev_buyer_fee_basis_points': 0,
#     'dev_seller_fee_basis_points': 100,
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': 0,
#     'opensea_seller_fee_basis_points': 250,
#     'buyer_fee_basis_points': 0,
#     'seller_fee_basis_points': 350,
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051'},
#    'permalink': 'https://opensea.io/assets/0x375ea781c49eafedde07afe6196f885761f166ae/279',
#    'collection': {'banner_image_url': 'https://lh3.googleusercontent.com/qLspBme9CU_VvkZpkQMXXjRFTy1JEMQJ_knfxxeQqTwYlSTqFC-NlCBAWuMm8dFNQdbKfuj4MlB19XD-OPp81x1Mo0S9M44YoWuW2w=s2500',
#     'chat_url': None,
#     'created_date': '2021-05-16T02:34:27.616469',
#     'default_to_fiat': False,
#     'description': 'A generative series of NFTs created using oracles.',
#     'dev_buyer_fee_basis_points': '0',
#     'dev_seller_fee_basis_points': '100',
#     'discord_url': 'https://discord.gg/yv8trsNXbJ',
#     'display_data': {'card_display_style': 'cover'},
#     'external_url': 'https://cryptotrunks.co',
#     'featured': False,
#     'featured_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'hidden': False,
#     'safelist_request_status': 'verified',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'is_subject_to_whitelist': False,
#     'large_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'medium_username': None,
#     'name': 'CryptoTrunks',
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': '0',
#     'opensea_seller_fee_basis_points': '250',
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'require_email': False,
#     'short_description': None,
#     'slug': 'cryptotrunks',
#     'telegram_url': None,
#     'twitter_username': 'thecryptotrunks',
#     'instagram_username': None,
#     'wiki_url': None},
#    'decimals': 0,
#    'token_metadata': 'https://service.cryptotrunks.co/token/279',
#    'owner': {'user': {'username': None},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/15.png',
#     'address': '0x1dc301854bfecb4ba03eb417579585c2b8ea12c1',
#     'config': ''},
#    'sell_orders': None,
#    'creator': {'user': {'username': 'TrunkDev'},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/7.png',
#     'address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'config': ''},
#    'traits': [{'trait_type': 'Age',
#      'value': 'Young',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 3327,
#      'order': None},
#     {'trait_type': 'Background',
#      'value': 'Grass – Soft',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 88,
#      'order': None},
#     {'trait_type': 'Edition',
#      'value': 'Genesis',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 1501,
#      'order': None},
#     {'trait_type': 'Type',
#      'value': 'Oak Treehouse',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 51,
#      'order': None},
#     {'trait_type': 'Sky',
#      'value': 'Night',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 871,
#      'order': None},
#     {'trait_type': 'Background',
#      'value': 'Forest – Leafy',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 3772,
#      'order': None}],
#    'last_sale': None,
#    'top_bid': None,
#    'listing_date': None,
#    'is_presale': False,
#    'transfer_fee_payment_token': None,
#    'transfer_fee': None},
#   {'id': 37037832,
#    'token_id': '802',
#    'num_sales': 0,
#    'background_color': None,
#    'image_url': 'https://lh3.googleusercontent.com/ZBjNRJ7ydJtX1flsrhUJ1ZayhEYmXzT2TXfdvygxSTWsh53pprdY-YRdIfJCuhVK_eaOu98ifOcwW3W0pbL2OaZZVtXSTLxH5zRN',
#    'image_preview_url': 'https://lh3.googleusercontent.com/ZBjNRJ7ydJtX1flsrhUJ1ZayhEYmXzT2TXfdvygxSTWsh53pprdY-YRdIfJCuhVK_eaOu98ifOcwW3W0pbL2OaZZVtXSTLxH5zRN=s250',
#    'image_thumbnail_url': 'https://lh3.googleusercontent.com/ZBjNRJ7ydJtX1flsrhUJ1ZayhEYmXzT2TXfdvygxSTWsh53pprdY-YRdIfJCuhVK_eaOu98ifOcwW3W0pbL2OaZZVtXSTLxH5zRN=s128',
#    'image_original_url': 'https://service.cryptotrunks.co/image.png?token=802',
#    'animation_url': None,
#    'animation_original_url': None,
#    'name': 'CryptoTrunk #802',
#    'description': None,
#    'external_link': 'https://cryptotrunks.co/individual-trunk-page.html?token=802',
#    'asset_contract': {'address': '0x375ea781c49eafedde07afe6196f885761f166ae',
#     'asset_contract_type': 'non-fungible',
#     'created_date': '2021-05-16T02:08:19.098730',
#     'name': 'CryptoTrunks',
#     'nft_version': '3.0',
#     'opensea_version': None,
#     'owner': 601,
#     'schema_name': 'ERC721',
#     'symbol': 'CT',
#     'total_supply': '0',
#     'description': 'A generative series of NFTs created using oracles.',
#     'external_link': 'https://cryptotrunks.co',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'default_to_fiat': False,
#     'dev_buyer_fee_basis_points': 0,
#     'dev_seller_fee_basis_points': 100,
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': 0,
#     'opensea_seller_fee_basis_points': 250,
#     'buyer_fee_basis_points': 0,
#     'seller_fee_basis_points': 350,
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051'},
#    'permalink': 'https://opensea.io/assets/0x375ea781c49eafedde07afe6196f885761f166ae/802',
#    'collection': {'banner_image_url': 'https://lh3.googleusercontent.com/qLspBme9CU_VvkZpkQMXXjRFTy1JEMQJ_knfxxeQqTwYlSTqFC-NlCBAWuMm8dFNQdbKfuj4MlB19XD-OPp81x1Mo0S9M44YoWuW2w=s2500',
#     'chat_url': None,
#     'created_date': '2021-05-16T02:34:27.616469',
#     'default_to_fiat': False,
#     'description': 'A generative series of NFTs created using oracles.',
#     'dev_buyer_fee_basis_points': '0',
#     'dev_seller_fee_basis_points': '100',
#     'discord_url': 'https://discord.gg/yv8trsNXbJ',
#     'display_data': {'card_display_style': 'cover'},
#     'external_url': 'https://cryptotrunks.co',
#     'featured': False,
#     'featured_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'hidden': False,
#     'safelist_request_status': 'verified',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'is_subject_to_whitelist': False,
#     'large_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'medium_username': None,
#     'name': 'CryptoTrunks',
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': '0',
#     'opensea_seller_fee_basis_points': '250',
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'require_email': False,
#     'short_description': None,
#     'slug': 'cryptotrunks',
#     'telegram_url': None,
#     'twitter_username': 'thecryptotrunks',
#     'instagram_username': None,
#     'wiki_url': None},
#    'decimals': 0,
#    'token_metadata': 'https://service.cryptotrunks.co/token/802',
#    'owner': {'user': {'username': None},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/15.png',
#     'address': '0x1dc301854bfecb4ba03eb417579585c2b8ea12c1',
#     'config': ''},
#    'sell_orders': None,
#    'creator': {'user': {'username': 'TrunkDev'},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/7.png',
#     'address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'config': ''},
#    'traits': [{'trait_type': 'Age',
#      'value': 'Young',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 3327,
#      'order': None},
#     {'trait_type': 'Edition',
#      'value': 'Genesis',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 1501,
#      'order': None},
#     {'trait_type': 'Element',
#      'value': 'Shooting Star',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 106,
#      'order': None},
#     {'trait_type': 'Sky',
#      'value': 'Clear Blue',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 51,
#      'order': None},
#     {'trait_type': 'Background',
#      'value': 'Clouds',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 100,
#      'order': None},
#     {'trait_type': 'Type',
#      'value': 'Ash Treehouse',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 50,
#      'order': None},
#     {'trait_type': 'Background',
#      'value': 'Mountains – Highlands',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 3169,
#      'order': None},
#     {'trait_type': 'Element',
#      'value': 'Ghost',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 431,
#      'order': None},
#     {'trait_type': 'Background',
#      'value': 'Forest – Leafy',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 3772,
#      'order': None}],
#    'last_sale': None,
#    'top_bid': None,
#    'listing_date': None,
#    'is_presale': False,
#    'transfer_fee_payment_token': None,
#    'transfer_fee': None},
#   {'id': 37037830,
#    'token_id': '1325',
#    'num_sales': 0,
#    'background_color': None,
#    'image_url': 'https://lh3.googleusercontent.com/8hNMl_LzXAA31rukR5jQOz3_YoRBoQBui18rGqH3YxsKlVTN0wu9T3pkRQgNwkwAWyZkPQNHVFYlRcQ75P9XYbutlmkoD7yixIoK-cY',
#    'image_preview_url': 'https://lh3.googleusercontent.com/8hNMl_LzXAA31rukR5jQOz3_YoRBoQBui18rGqH3YxsKlVTN0wu9T3pkRQgNwkwAWyZkPQNHVFYlRcQ75P9XYbutlmkoD7yixIoK-cY=s250',
#    'image_thumbnail_url': 'https://lh3.googleusercontent.com/8hNMl_LzXAA31rukR5jQOz3_YoRBoQBui18rGqH3YxsKlVTN0wu9T3pkRQgNwkwAWyZkPQNHVFYlRcQ75P9XYbutlmkoD7yixIoK-cY=s128',
#    'image_original_url': 'https://service.cryptotrunks.co/image.png?token=1325',
#    'animation_url': None,
#    'animation_original_url': None,
#    'name': 'CryptoTrunk #1325',
#    'description': None,
#    'external_link': 'https://cryptotrunks.co/individual-trunk-page.html?token=1325',
#    'asset_contract': {'address': '0x375ea781c49eafedde07afe6196f885761f166ae',
#     'asset_contract_type': 'non-fungible',
#     'created_date': '2021-05-16T02:08:19.098730',
#     'name': 'CryptoTrunks',
#     'nft_version': '3.0',
#     'opensea_version': None,
#     'owner': 601,
#     'schema_name': 'ERC721',
#     'symbol': 'CT',
#     'total_supply': '0',
#     'description': 'A generative series of NFTs created using oracles.',
#     'external_link': 'https://cryptotrunks.co',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'default_to_fiat': False,
#     'dev_buyer_fee_basis_points': 0,
#     'dev_seller_fee_basis_points': 100,
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': 0,
#     'opensea_seller_fee_basis_points': 250,
#     'buyer_fee_basis_points': 0,
#     'seller_fee_basis_points': 350,
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051'},
#    'permalink': 'https://opensea.io/assets/0x375ea781c49eafedde07afe6196f885761f166ae/1325',
#    'collection': {'banner_image_url': 'https://lh3.googleusercontent.com/qLspBme9CU_VvkZpkQMXXjRFTy1JEMQJ_knfxxeQqTwYlSTqFC-NlCBAWuMm8dFNQdbKfuj4MlB19XD-OPp81x1Mo0S9M44YoWuW2w=s2500',
#     'chat_url': None,
#     'created_date': '2021-05-16T02:34:27.616469',
#     'default_to_fiat': False,
#     'description': 'A generative series of NFTs created using oracles.',
#     'dev_buyer_fee_basis_points': '0',
#     'dev_seller_fee_basis_points': '100',
#     'discord_url': 'https://discord.gg/yv8trsNXbJ',
#     'display_data': {'card_display_style': 'cover'},
#     'external_url': 'https://cryptotrunks.co',
#     'featured': False,
#     'featured_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'hidden': False,
#     'safelist_request_status': 'verified',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'is_subject_to_whitelist': False,
#     'large_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'medium_username': None,
#     'name': 'CryptoTrunks',
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': '0',
#     'opensea_seller_fee_basis_points': '250',
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'require_email': False,
#     'short_description': None,
#     'slug': 'cryptotrunks',
#     'telegram_url': None,
#     'twitter_username': 'thecryptotrunks',
#     'instagram_username': None,
#     'wiki_url': None},
#    'decimals': 0,
#    'token_metadata': 'https://service.cryptotrunks.co/token/1325',
#    'owner': {'user': {'username': None},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/15.png',
#     'address': '0x1dc301854bfecb4ba03eb417579585c2b8ea12c1',
#     'config': ''},
#    'sell_orders': None,
#    'creator': {'user': {'username': 'TrunkDev'},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/7.png',
#     'address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'config': ''},
#    'traits': [{'trait_type': 'Element',
#      'value': 'Golden Birds in Flight',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 433,
#      'order': None},
#     {'trait_type': 'Age',
#      'value': 'Young',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 3327,
#      'order': None},
#     {'trait_type': 'Edition',
#      'value': 'Genesis',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 1501,
#      'order': None},
#     {'trait_type': 'Background',
#      'value': 'Clouds',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 100,
#      'order': None},
#     {'trait_type': 'Type',
#      'value': 'Spruce Treehouse',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 47,
#      'order': None},
#     {'trait_type': 'Sky',
#      'value': 'Night',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 871,
#      'order': None}],
#    'last_sale': None,
#    'top_bid': None,
#    'listing_date': None,
#    'is_presale': False,
#    'transfer_fee_payment_token': None,
#    'transfer_fee': None},
#   {'id': 37037828,
#    'token_id': '348',
#    'num_sales': 0,
#    'background_color': None,
#    'image_url': 'https://lh3.googleusercontent.com/FiLcpQePvfVSZ12QsJZzJBtfsY9JXdOJRj2p87TdXxUombn3okZu93nrV6VEiVCvmX1kly5UOfQX817HqZD7S9xDWCSG3cgGG7ygcQ',
#    'image_preview_url': 'https://lh3.googleusercontent.com/FiLcpQePvfVSZ12QsJZzJBtfsY9JXdOJRj2p87TdXxUombn3okZu93nrV6VEiVCvmX1kly5UOfQX817HqZD7S9xDWCSG3cgGG7ygcQ=s250',
#    'image_thumbnail_url': 'https://lh3.googleusercontent.com/FiLcpQePvfVSZ12QsJZzJBtfsY9JXdOJRj2p87TdXxUombn3okZu93nrV6VEiVCvmX1kly5UOfQX817HqZD7S9xDWCSG3cgGG7ygcQ=s128',
#    'image_original_url': 'https://service.cryptotrunks.co/image.png?token=348',
#    'animation_url': None,
#    'animation_original_url': None,
#    'name': 'CryptoTrunk #348',
#    'description': None,
#    'external_link': 'https://cryptotrunks.co/individual-trunk-page.html?token=348',
#    'asset_contract': {'address': '0x375ea781c49eafedde07afe6196f885761f166ae',
#     'asset_contract_type': 'non-fungible',
#     'created_date': '2021-05-16T02:08:19.098730',
#     'name': 'CryptoTrunks',
#     'nft_version': '3.0',
#     'opensea_version': None,
#     'owner': 601,
#     'schema_name': 'ERC721',
#     'symbol': 'CT',
#     'total_supply': '0',
#     'description': 'A generative series of NFTs created using oracles.',
#     'external_link': 'https://cryptotrunks.co',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'default_to_fiat': False,
#     'dev_buyer_fee_basis_points': 0,
#     'dev_seller_fee_basis_points': 100,
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': 0,
#     'opensea_seller_fee_basis_points': 250,
#     'buyer_fee_basis_points': 0,
#     'seller_fee_basis_points': 350,
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051'},
#    'permalink': 'https://opensea.io/assets/0x375ea781c49eafedde07afe6196f885761f166ae/348',
#    'collection': {'banner_image_url': 'https://lh3.googleusercontent.com/qLspBme9CU_VvkZpkQMXXjRFTy1JEMQJ_knfxxeQqTwYlSTqFC-NlCBAWuMm8dFNQdbKfuj4MlB19XD-OPp81x1Mo0S9M44YoWuW2w=s2500',
#     'chat_url': None,
#     'created_date': '2021-05-16T02:34:27.616469',
#     'default_to_fiat': False,
#     'description': 'A generative series of NFTs created using oracles.',
#     'dev_buyer_fee_basis_points': '0',
#     'dev_seller_fee_basis_points': '100',
#     'discord_url': 'https://discord.gg/yv8trsNXbJ',
#     'display_data': {'card_display_style': 'cover'},
#     'external_url': 'https://cryptotrunks.co',
#     'featured': False,
#     'featured_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'hidden': False,
#     'safelist_request_status': 'verified',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'is_subject_to_whitelist': False,
#     'large_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'medium_username': None,
#     'name': 'CryptoTrunks',
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': '0',
#     'opensea_seller_fee_basis_points': '250',
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'require_email': False,
#     'short_description': None,
#     'slug': 'cryptotrunks',
#     'telegram_url': None,
#     'twitter_username': 'thecryptotrunks',
#     'instagram_username': None,
#     'wiki_url': None},
#    'decimals': 0,
#    'token_metadata': 'https://service.cryptotrunks.co/token/348',
#    'owner': {'user': {'username': None},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/15.png',
#     'address': '0x1dc301854bfecb4ba03eb417579585c2b8ea12c1',
#     'config': ''},
#    'sell_orders': None,
#    'creator': {'user': {'username': 'TrunkDev'},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/7.png',
#     'address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'config': ''},
#    'traits': [{'trait_type': 'Type',
#      'value': 'Maple Treehouse',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 47,
#      'order': None},
#     {'trait_type': 'Age',
#      'value': 'Elder',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 2758,
#      'order': None},
#     {'trait_type': 'Edition',
#      'value': 'Genesis',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 1501,
#      'order': None},
#     {'trait_type': 'Sky',
#      'value': 'Volcano with Town and Savanah Grass',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 31,
#      'order': None},
#     {'trait_type': 'Element',
#      'value': 'Golden Hearts',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 140,
#      'order': None}],
#    'last_sale': None,
#    'top_bid': None,
#    'listing_date': None,
#    'is_presale': False,
#    'transfer_fee_payment_token': None,
#    'transfer_fee': None},
#   {'id': 37037826,
#    'token_id': '871',
#    'num_sales': 0,
#    'background_color': None,
#    'image_url': 'https://lh3.googleusercontent.com/p4fNP2fxlWZ5tuioqSMD3vkkDRQfSaQ6eNdKbKqF9gJrubPpqmdgYU9HNOmmQTIr8luxeKOGUfgNkwhoAtRAMOIQlr8ctZ0NmT7RKts',
#    'image_preview_url': 'https://lh3.googleusercontent.com/p4fNP2fxlWZ5tuioqSMD3vkkDRQfSaQ6eNdKbKqF9gJrubPpqmdgYU9HNOmmQTIr8luxeKOGUfgNkwhoAtRAMOIQlr8ctZ0NmT7RKts=s250',
#    'image_thumbnail_url': 'https://lh3.googleusercontent.com/p4fNP2fxlWZ5tuioqSMD3vkkDRQfSaQ6eNdKbKqF9gJrubPpqmdgYU9HNOmmQTIr8luxeKOGUfgNkwhoAtRAMOIQlr8ctZ0NmT7RKts=s128',
#    'image_original_url': 'https://service.cryptotrunks.co/image.png?token=871',
#    'animation_url': None,
#    'animation_original_url': None,
#    'name': 'CryptoTrunk #871',
#    'description': None,
#    'external_link': 'https://cryptotrunks.co/individual-trunk-page.html?token=871',
#    'asset_contract': {'address': '0x375ea781c49eafedde07afe6196f885761f166ae',
#     'asset_contract_type': 'non-fungible',
#     'created_date': '2021-05-16T02:08:19.098730',
#     'name': 'CryptoTrunks',
#     'nft_version': '3.0',
#     'opensea_version': None,
#     'owner': 601,
#     'schema_name': 'ERC721',
#     'symbol': 'CT',
#     'total_supply': '0',
#     'description': 'A generative series of NFTs created using oracles.',
#     'external_link': 'https://cryptotrunks.co',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'default_to_fiat': False,
#     'dev_buyer_fee_basis_points': 0,
#     'dev_seller_fee_basis_points': 100,
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': 0,
#     'opensea_seller_fee_basis_points': 250,
#     'buyer_fee_basis_points': 0,
#     'seller_fee_basis_points': 350,
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051'},
#    'permalink': 'https://opensea.io/assets/0x375ea781c49eafedde07afe6196f885761f166ae/871',
#    'collection': {'banner_image_url': 'https://lh3.googleusercontent.com/qLspBme9CU_VvkZpkQMXXjRFTy1JEMQJ_knfxxeQqTwYlSTqFC-NlCBAWuMm8dFNQdbKfuj4MlB19XD-OPp81x1Mo0S9M44YoWuW2w=s2500',
#     'chat_url': None,
#     'created_date': '2021-05-16T02:34:27.616469',
#     'default_to_fiat': False,
#     'description': 'A generative series of NFTs created using oracles.',
#     'dev_buyer_fee_basis_points': '0',
#     'dev_seller_fee_basis_points': '100',
#     'discord_url': 'https://discord.gg/yv8trsNXbJ',
#     'display_data': {'card_display_style': 'cover'},
#     'external_url': 'https://cryptotrunks.co',
#     'featured': False,
#     'featured_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'hidden': False,
#     'safelist_request_status': 'verified',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'is_subject_to_whitelist': False,
#     'large_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'medium_username': None,
#     'name': 'CryptoTrunks',
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': '0',
#     'opensea_seller_fee_basis_points': '250',
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'require_email': False,
#     'short_description': None,
#     'slug': 'cryptotrunks',
#     'telegram_url': None,
#     'twitter_username': 'thecryptotrunks',
#     'instagram_username': None,
#     'wiki_url': None},
#    'decimals': 0,
#    'token_metadata': 'https://service.cryptotrunks.co/token/871',
#    'owner': {'user': {'username': None},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/15.png',
#     'address': '0x1dc301854bfecb4ba03eb417579585c2b8ea12c1',
#     'config': ''},
#    'sell_orders': None,
#    'creator': {'user': {'username': 'TrunkDev'},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/7.png',
#     'address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'config': ''},
#    'traits': [{'trait_type': 'Element',
#      'value': 'Golden Gravestone',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 260,
#      'order': None},
#     {'trait_type': 'Age',
#      'value': 'Elder',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 2758,
#      'order': None},
#     {'trait_type': 'Edition',
#      'value': 'Genesis',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 1501,
#      'order': None},
#     {'trait_type': 'Sky',
#      'value': 'Beach and Desert with Oasis',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 20,
#      'order': None},
#     {'trait_type': 'Type',
#      'value': 'Rainbow Spruce',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 33,
#      'order': None}],
#    'last_sale': None,
#    'top_bid': None,
#    'listing_date': None,
#    'is_presale': False,
#    'transfer_fee_payment_token': None,
#    'transfer_fee': None},
#   {'id': 37037825,
#    'token_id': '1394',
#    'num_sales': 0,
#    'background_color': None,
#    'image_url': 'https://lh3.googleusercontent.com/apK3O4PZAzbb7bClzZq8kLGf_wDRtp60tom46NvbBynFd-BehTuyxYlGVgkjt0zCNZpEg0ztjgGsLKyrjL1XJ-ijbZHCyu9NjG2do6g',
#    'image_preview_url': 'https://lh3.googleusercontent.com/apK3O4PZAzbb7bClzZq8kLGf_wDRtp60tom46NvbBynFd-BehTuyxYlGVgkjt0zCNZpEg0ztjgGsLKyrjL1XJ-ijbZHCyu9NjG2do6g=s250',
#    'image_thumbnail_url': 'https://lh3.googleusercontent.com/apK3O4PZAzbb7bClzZq8kLGf_wDRtp60tom46NvbBynFd-BehTuyxYlGVgkjt0zCNZpEg0ztjgGsLKyrjL1XJ-ijbZHCyu9NjG2do6g=s128',
#    'image_original_url': 'https://service.cryptotrunks.co/image.png?token=1394',
#    'animation_url': None,
#    'animation_original_url': None,
#    'name': 'CryptoTrunk #1394',
#    'description': None,
#    'external_link': 'https://cryptotrunks.co/individual-trunk-page.html?token=1394',
#    'asset_contract': {'address': '0x375ea781c49eafedde07afe6196f885761f166ae',
#     'asset_contract_type': 'non-fungible',
#     'created_date': '2021-05-16T02:08:19.098730',
#     'name': 'CryptoTrunks',
#     'nft_version': '3.0',
#     'opensea_version': None,
#     'owner': 601,
#     'schema_name': 'ERC721',
#     'symbol': 'CT',
#     'total_supply': '0',
#     'description': 'A generative series of NFTs created using oracles.',
#     'external_link': 'https://cryptotrunks.co',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'default_to_fiat': False,
#     'dev_buyer_fee_basis_points': 0,
#     'dev_seller_fee_basis_points': 100,
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': 0,
#     'opensea_seller_fee_basis_points': 250,
#     'buyer_fee_basis_points': 0,
#     'seller_fee_basis_points': 350,
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051'},
#    'permalink': 'https://opensea.io/assets/0x375ea781c49eafedde07afe6196f885761f166ae/1394',
#    'collection': {'banner_image_url': 'https://lh3.googleusercontent.com/qLspBme9CU_VvkZpkQMXXjRFTy1JEMQJ_knfxxeQqTwYlSTqFC-NlCBAWuMm8dFNQdbKfuj4MlB19XD-OPp81x1Mo0S9M44YoWuW2w=s2500',
#     'chat_url': None,
#     'created_date': '2021-05-16T02:34:27.616469',
#     'default_to_fiat': False,
#     'description': 'A generative series of NFTs created using oracles.',
#     'dev_buyer_fee_basis_points': '0',
#     'dev_seller_fee_basis_points': '100',
#     'discord_url': 'https://discord.gg/yv8trsNXbJ',
#     'display_data': {'card_display_style': 'cover'},
#     'external_url': 'https://cryptotrunks.co',
#     'featured': False,
#     'featured_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'hidden': False,
#     'safelist_request_status': 'verified',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'is_subject_to_whitelist': False,
#     'large_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'medium_username': None,
#     'name': 'CryptoTrunks',
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': '0',
#     'opensea_seller_fee_basis_points': '250',
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'require_email': False,
#     'short_description': None,
#     'slug': 'cryptotrunks',
#     'telegram_url': None,
#     'twitter_username': 'thecryptotrunks',
#     'instagram_username': None,
#     'wiki_url': None},
#    'decimals': 0,
#    'token_metadata': 'https://service.cryptotrunks.co/token/1394',
#    'owner': {'user': {'username': None},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/15.png',
#     'address': '0x1dc301854bfecb4ba03eb417579585c2b8ea12c1',
#     'config': ''},
#    'sell_orders': None,
#    'creator': {'user': {'username': 'TrunkDev'},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/7.png',
#     'address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'config': ''},
#    'traits': [{'trait_type': 'Type',
#      'value': 'Cherry Empress',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 76,
#      'order': None},
#     {'trait_type': 'Element',
#      'value': 'Golden Monkey',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 185,
#      'order': None},
#     {'trait_type': 'Sky',
#      'value': 'Abstract',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 97,
#      'order': None},
#     {'trait_type': 'Edition',
#      'value': 'Genesis',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 1501,
#      'order': None},
#     {'trait_type': 'Age',
#      'value': 'Sapling',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 2793,
#      'order': None}],
#    'last_sale': None,
#    'top_bid': None,
#    'listing_date': None,
#    'is_presale': False,
#    'transfer_fee_payment_token': None,
#    'transfer_fee': None},
#   {'id': 37037823,
#    'token_id': '417',
#    'num_sales': 0,
#    'background_color': None,
#    'image_url': 'https://lh3.googleusercontent.com/1UkEkMOPFFcO63dh7MzG0A-J0Kzce9692XAvaIKWrIwRSgvfxllTYWFaol4LhoC6IRwTLqkR4VkfTKiD3chMg2Eg3f0TUjiOBq6M0g',
# ...
#    'token_id': '791',
#    'num_sales': 0,
#    'background_color': None,
#    'image_url': 'https://lh3.googleusercontent.com/DAXUgeZfPPeOVOK3H9R7QCc6qxOaXwUO9Pd0NoADwmrEUWVkBF9DvxNIFP-2TEACKlXMlT31dPzvgUy4Qs-UhAepL5OPhjgUc1KDtQw',
#    'image_preview_url': 'https://lh3.googleusercontent.com/DAXUgeZfPPeOVOK3H9R7QCc6qxOaXwUO9Pd0NoADwmrEUWVkBF9DvxNIFP-2TEACKlXMlT31dPzvgUy4Qs-UhAepL5OPhjgUc1KDtQw=s250',
#    'image_thumbnail_url': 'https://lh3.googleusercontent.com/DAXUgeZfPPeOVOK3H9R7QCc6qxOaXwUO9Pd0NoADwmrEUWVkBF9DvxNIFP-2TEACKlXMlT31dPzvgUy4Qs-UhAepL5OPhjgUc1KDtQw=s128',
#    'image_original_url': 'https://service.cryptotrunks.co/image.png?token=791',
#    'animation_url': None,
#    'animation_original_url': None,
#    'name': 'CryptoTrunk #791',
#    'description': None,
#    'external_link': 'https://cryptotrunks.co/individual-trunk-page.html?token=791',
#    'asset_contract': {'address': '0x375ea781c49eafedde07afe6196f885761f166ae',
#     'asset_contract_type': 'non-fungible',
#     'created_date': '2021-05-16T02:08:19.098730',
#     'name': 'CryptoTrunks',
#     'nft_version': '3.0',
#     'opensea_version': None,
#     'owner': 601,
#     'schema_name': 'ERC721',
#     'symbol': 'CT',
#     'total_supply': '0',
#     'description': 'A generative series of NFTs created using oracles.',
#     'external_link': 'https://cryptotrunks.co',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'default_to_fiat': False,
#     'dev_buyer_fee_basis_points': 0,
#     'dev_seller_fee_basis_points': 100,
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': 0,
#     'opensea_seller_fee_basis_points': 250,
#     'buyer_fee_basis_points': 0,
#     'seller_fee_basis_points': 350,
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051'},
#    'permalink': 'https://opensea.io/assets/0x375ea781c49eafedde07afe6196f885761f166ae/791',
#    'collection': {'banner_image_url': 'https://lh3.googleusercontent.com/qLspBme9CU_VvkZpkQMXXjRFTy1JEMQJ_knfxxeQqTwYlSTqFC-NlCBAWuMm8dFNQdbKfuj4MlB19XD-OPp81x1Mo0S9M44YoWuW2w=s2500',
#     'chat_url': None,
#     'created_date': '2021-05-16T02:34:27.616469',
#     'default_to_fiat': False,
#     'description': 'A generative series of NFTs created using oracles.',
#     'dev_buyer_fee_basis_points': '0',
#     'dev_seller_fee_basis_points': '100',
#     'discord_url': 'https://discord.gg/yv8trsNXbJ',
#     'display_data': {'card_display_style': 'cover'},
#     'external_url': 'https://cryptotrunks.co',
#     'featured': False,
#     'featured_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'hidden': False,
#     'safelist_request_status': 'verified',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'is_subject_to_whitelist': False,
#     'large_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'medium_username': None,
#     'name': 'CryptoTrunks',
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': '0',
#     'opensea_seller_fee_basis_points': '250',
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'require_email': False,
#     'short_description': None,
#     'slug': 'cryptotrunks',
#     'telegram_url': None,
#     'twitter_username': 'thecryptotrunks',
#     'instagram_username': None,
#     'wiki_url': None},
#    'decimals': 0,
#    'token_metadata': 'https://service.cryptotrunks.co/token/791',
#    'owner': {'user': {'username': None},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/15.png',
#     'address': '0x1dc301854bfecb4ba03eb417579585c2b8ea12c1',
#     'config': ''},
#    'sell_orders': None,
#    'creator': {'user': {'username': 'TrunkDev'},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/7.png',
#     'address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'config': ''},
#    'traits': [{'trait_type': 'Background',
#      'value': 'Urban – Town',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 1526,
#      'order': None},
#     {'trait_type': 'Background',
#      'value': 'Grass – Riverside',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 2662,
#      'order': None},
#     {'trait_type': 'Sky',
#      'value': 'Space',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 51,
#      'order': None},
#     {'trait_type': 'Type',
#      'value': 'Golden Ash',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 61,
#      'order': None},
#     {'trait_type': 'Edition',
#      'value': 'Genesis',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 1501,
#      'order': None},
#     {'trait_type': 'Age',
#      'value': 'Sapling',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 2793,
#      'order': None}],
#    'last_sale': None,
#    'top_bid': None,
#    'listing_date': None,
#    'is_presale': False,
#    'transfer_fee_payment_token': None,
#    'transfer_fee': None},
#   {'id': 37036034,
#    'token_id': '1314',
#    'num_sales': 0,
#    'background_color': None,
#    'image_url': 'https://lh3.googleusercontent.com/odFnSxtf4s2z0aCMLYPG0RVeWvUnj8tvdOaoRKaStoXl7cDzG_cVtl3w_sretvsh_n3cOrmIq7SdMqu9GWLGJj2q_o1klnIYG3pKkg',
#    'image_preview_url': 'https://lh3.googleusercontent.com/odFnSxtf4s2z0aCMLYPG0RVeWvUnj8tvdOaoRKaStoXl7cDzG_cVtl3w_sretvsh_n3cOrmIq7SdMqu9GWLGJj2q_o1klnIYG3pKkg=s250',
#    'image_thumbnail_url': 'https://lh3.googleusercontent.com/odFnSxtf4s2z0aCMLYPG0RVeWvUnj8tvdOaoRKaStoXl7cDzG_cVtl3w_sretvsh_n3cOrmIq7SdMqu9GWLGJj2q_o1klnIYG3pKkg=s128',
#    'image_original_url': 'https://service.cryptotrunks.co/image.png?token=1314',
#    'animation_url': None,
#    'animation_original_url': None,
#    'name': 'CryptoTrunk #1314',
#    'description': None,
#    'external_link': 'https://cryptotrunks.co/individual-trunk-page.html?token=1314',
#    'asset_contract': {'address': '0x375ea781c49eafedde07afe6196f885761f166ae',
#     'asset_contract_type': 'non-fungible',
#     'created_date': '2021-05-16T02:08:19.098730',
#     'name': 'CryptoTrunks',
#     'nft_version': '3.0',
#     'opensea_version': None,
#     'owner': 601,
#     'schema_name': 'ERC721',
#     'symbol': 'CT',
#     'total_supply': '0',
#     'description': 'A generative series of NFTs created using oracles.',
#     'external_link': 'https://cryptotrunks.co',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'default_to_fiat': False,
#     'dev_buyer_fee_basis_points': 0,
#     'dev_seller_fee_basis_points': 100,
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': 0,
#     'opensea_seller_fee_basis_points': 250,
#     'buyer_fee_basis_points': 0,
#     'seller_fee_basis_points': 350,
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051'},
#    'permalink': 'https://opensea.io/assets/0x375ea781c49eafedde07afe6196f885761f166ae/1314',
#    'collection': {'banner_image_url': 'https://lh3.googleusercontent.com/qLspBme9CU_VvkZpkQMXXjRFTy1JEMQJ_knfxxeQqTwYlSTqFC-NlCBAWuMm8dFNQdbKfuj4MlB19XD-OPp81x1Mo0S9M44YoWuW2w=s2500',
#     'chat_url': None,
#     'created_date': '2021-05-16T02:34:27.616469',
#     'default_to_fiat': False,
#     'description': 'A generative series of NFTs created using oracles.',
#     'dev_buyer_fee_basis_points': '0',
#     'dev_seller_fee_basis_points': '100',
#     'discord_url': 'https://discord.gg/yv8trsNXbJ',
#     'display_data': {'card_display_style': 'cover'},
#     'external_url': 'https://cryptotrunks.co',
#     'featured': False,
#     'featured_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'hidden': False,
#     'safelist_request_status': 'verified',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'is_subject_to_whitelist': False,
#     'large_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'medium_username': None,
#     'name': 'CryptoTrunks',
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': '0',
#     'opensea_seller_fee_basis_points': '250',
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'require_email': False,
#     'short_description': None,
#     'slug': 'cryptotrunks',
#     'telegram_url': None,
#     'twitter_username': 'thecryptotrunks',
#     'instagram_username': None,
#     'wiki_url': None},
#    'decimals': 0,
#    'token_metadata': 'https://service.cryptotrunks.co/token/1314',
#    'owner': {'user': {'username': None},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/15.png',
#     'address': '0x1dc301854bfecb4ba03eb417579585c2b8ea12c1',
#     'config': ''},
#    'sell_orders': None,
#    'creator': {'user': {'username': 'TrunkDev'},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/7.png',
#     'address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'config': ''},
#    'traits': [{'trait_type': 'Age',
#      'value': 'Ancient',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 893,
#      'order': None},
#     {'trait_type': 'Background',
#      'value': 'Urban – Town',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 1526,
#      'order': None},
#     {'trait_type': 'Background',
#      'value': 'Grass – Riverside',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 2662,
#      'order': None},
#     {'trait_type': 'Edition',
#      'value': 'Genesis',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 1501,
#      'order': None},
#     {'trait_type': 'Type',
#      'value': 'Poplar Treehouse',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 49,
#      'order': None},
#     {'trait_type': 'Sky',
#      'value': 'Dusk',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 534,
#      'order': None}],
#    'last_sale': None,
#    'top_bid': None,
#    'listing_date': None,
#    'is_presale': False,
#    'transfer_fee_payment_token': None,
#    'transfer_fee': None},
#   {'id': 37036030,
#    'token_id': '337',
#    'num_sales': 0,
#    'background_color': None,
#    'image_url': 'https://lh3.googleusercontent.com/hQtfBj0w-nBog-bh200ONx8broPctaf4rKeRdso3V2LUYvoSGXd7geGbh5IZVR5z_fiUNDAWryxA-X5RoLnFl_I71fczN0Hj-6SFVA',
#    'image_preview_url': 'https://lh3.googleusercontent.com/hQtfBj0w-nBog-bh200ONx8broPctaf4rKeRdso3V2LUYvoSGXd7geGbh5IZVR5z_fiUNDAWryxA-X5RoLnFl_I71fczN0Hj-6SFVA=s250',
#    'image_thumbnail_url': 'https://lh3.googleusercontent.com/hQtfBj0w-nBog-bh200ONx8broPctaf4rKeRdso3V2LUYvoSGXd7geGbh5IZVR5z_fiUNDAWryxA-X5RoLnFl_I71fczN0Hj-6SFVA=s128',
#    'image_original_url': 'https://service.cryptotrunks.co/image.png?token=337',
#    'animation_url': None,
#    'animation_original_url': None,
#    'name': 'CryptoTrunk #337',
#    'description': None,
#    'external_link': 'https://cryptotrunks.co/individual-trunk-page.html?token=337',
#    'asset_contract': {'address': '0x375ea781c49eafedde07afe6196f885761f166ae',
#     'asset_contract_type': 'non-fungible',
#     'created_date': '2021-05-16T02:08:19.098730',
#     'name': 'CryptoTrunks',
#     'nft_version': '3.0',
#     'opensea_version': None,
#     'owner': 601,
#     'schema_name': 'ERC721',
#     'symbol': 'CT',
#     'total_supply': '0',
#     'description': 'A generative series of NFTs created using oracles.',
#     'external_link': 'https://cryptotrunks.co',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'default_to_fiat': False,
#     'dev_buyer_fee_basis_points': 0,
#     'dev_seller_fee_basis_points': 100,
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': 0,
#     'opensea_seller_fee_basis_points': 250,
#     'buyer_fee_basis_points': 0,
#     'seller_fee_basis_points': 350,
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051'},
#    'permalink': 'https://opensea.io/assets/0x375ea781c49eafedde07afe6196f885761f166ae/337',
#    'collection': {'banner_image_url': 'https://lh3.googleusercontent.com/qLspBme9CU_VvkZpkQMXXjRFTy1JEMQJ_knfxxeQqTwYlSTqFC-NlCBAWuMm8dFNQdbKfuj4MlB19XD-OPp81x1Mo0S9M44YoWuW2w=s2500',
#     'chat_url': None,
#     'created_date': '2021-05-16T02:34:27.616469',
#     'default_to_fiat': False,
#     'description': 'A generative series of NFTs created using oracles.',
#     'dev_buyer_fee_basis_points': '0',
#     'dev_seller_fee_basis_points': '100',
#     'discord_url': 'https://discord.gg/yv8trsNXbJ',
#     'display_data': {'card_display_style': 'cover'},
#     'external_url': 'https://cryptotrunks.co',
#     'featured': False,
#     'featured_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'hidden': False,
#     'safelist_request_status': 'verified',
#     'image_url': 'https://lh3.googleusercontent.com/oZ3rNvsIZGyj_BInkVOQotVWjoToROEwBEOAKOiElByQcV_zHqYUE61Nds2g_s1rg0vEjSV_ADix8jForAya5zZPtWnamJNcdBWWcA=s120',
#     'is_subject_to_whitelist': False,
#     'large_image_url': 'https://lh3.googleusercontent.com/qNfF0ODxPJnCi7UtnKvuMsDNTpxf9Qtw3q3ShLwrPrwjOTOM2gWCpUfz0nLKHelGyGS9Poy6ilRcCleVn_RGlxeCWrR2p7E1zV1K=s300',
#     'medium_username': None,
#     'name': 'CryptoTrunks',
#     'only_proxied_transfers': False,
#     'opensea_buyer_fee_basis_points': '0',
#     'opensea_seller_fee_basis_points': '250',
#     'payout_address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'require_email': False,
#     'short_description': None,
#     'slug': 'cryptotrunks',
#     'telegram_url': None,
#     'twitter_username': 'thecryptotrunks',
#     'instagram_username': None,
#     'wiki_url': None},
#    'decimals': 0,
#    'token_metadata': 'https://service.cryptotrunks.co/token/337',
#    'owner': {'user': {'username': None},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/15.png',
#     'address': '0x1dc301854bfecb4ba03eb417579585c2b8ea12c1',
#     'config': ''},
#    'sell_orders': None,
#    'creator': {'user': {'username': 'TrunkDev'},
#     'profile_img_url': 'https://storage.googleapis.com/opensea-static/opensea-profile/7.png',
#     'address': '0xf459b83f676467e55ed557a45b1e64569450f051',
#     'config': ''},
#    'traits': [{'trait_type': 'Sky',
#      'value': 'Trees – Deep Forest',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 53,
#      'order': None},
#     {'trait_type': 'Background',
#      'value': 'Forest – Mixed',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 3853,
#      'order': None},
#     {'trait_type': 'Type',
#      'value': 'Birch Treehouse',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 48,
#      'order': None},
#     {'trait_type': 'Background',
#      'value': 'Grass – Soft',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 88,
#      'order': None},
#     {'trait_type': 'Edition',
#      'value': 'Genesis',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 1501,
#      'order': None},
#     {'trait_type': 'Age',
#      'value': 'Adult',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 4225,
#      'order': None},
#     {'trait_type': 'Background',
#      'value': 'Deep Forest – Leafy',
#      'display_type': None,
#      'max_value': None,
#      'trait_count': 3744,
#      'order': None}],
#    'last_sale': None,
#    'top_bid': None,
#    'listing_date': None,
#    'is_presale': False,
#    'transfer_fee_payment_token': None,
#    'transfer_fee': None}]}

# %% [markdown]
# # Data preprocessing

# %%
#List of NFT_IDs
List_of_50_NFTs = Crypto_trunks_50_json['assets']
NFT_ID =[List_of_50_NFTs[NFT]['token_id'] 
          for NFT in range(len(Crypto_trunks_50_json['assets']))]

print(len(NFT_ID))
print(NFT_ID[0:5])
# Out:
# 50
# ['210', '733', '1256', '279', '802']

# %%
#Trait_types in JSON
List_of_Traits_in_all_NFTs = [
    List_of_50_NFTs[NFT]['traits'] 
    for NFT in range(len(Crypto_trunks_50_json['assets']))]
List_of_Traits_in_all_NFTs

print(len(List_of_Traits_in_all_NFTs))
print(List_of_Traits_in_all_NFTs[0])
# Out:
# 50
# [{'trait_type': 'Type', 'value': 'Burning Ash', 'display_type': None, 'max_value': None, 'trait_count': 13, 'order': None}, {'trait_type': 'Age', 'value': 'Elder', 'display_type': None, 'max_value': None, 'trait_count': 2758, 'order': None}, {'trait_type': 'Edition', 'value': 'Genesis', 'display_type': None, 'max_value': None, 'trait_count': 1501, 'order': None}, {'trait_type': 'Element', 'value': 'Among Us – Orange', 'display_type': None, 'max_value': None, 'trait_count': 11, 'order': None}, {'trait_type': 'Sky', 'value': 'Underwater City and Road', 'display_type': None, 'max_value': None, 'trait_count': 21, 'order': None}]

# %% [markdown]
# # Goal 01:  Traits_Rarity_Score

# %% [markdown]
# 1. Create Lists for the DataFrame

# %%
# Trait_types
Trait_types_for_NFTs = [
    List_of_Traits_in_all_NFTs[NFT][TRAITE]['trait_type'] 
    for NFT in range(len(List_of_Traits_in_all_NFTs))
    for TRAITE in range(len(List_of_Traits_in_all_NFTs[NFT]))
    ]
Trait_types_for_NFTs[:5]
# Out:
# ['Type', 'Age', 'Edition', 'Element', 'Sky']

# %%
#Trait_Values
#How to generate a value for every trait?
Trait_value_for_NFTs = [
    List_of_Traits_in_all_NFTs[NFT][TRAITE]['value'] 
    for NFT in range(len(List_of_Traits_in_all_NFTs))
    for TRAITE in range(len(List_of_Traits_in_all_NFTs[NFT]))
    ]

print(len(Trait_value_for_NFTs))
print(Trait_value_for_NFTs[:5])
# Out:
# 301
# ['Burning Ash', 'Elder', 'Genesis', 'Among Us – Orange', 'Underwater City and Road']

# %%
#Trait_counts
Trait_count_for_NFTs = [
    List_of_Traits_in_all_NFTs[NFT][TRAITE]['trait_count'] 
    for NFT in range(len(List_of_Traits_in_all_NFTs))
    for TRAITE in range(len(List_of_Traits_in_all_NFTs[NFT]))
    ]

print(len(Trait_count_for_NFTs))
print(Trait_count_for_NFTs[0:5])
# Out:
# 301
# [13, 2758, 1501, 11, 21]

# %%
#Percentages%
#Trait_type_rarity_percentages

Total_amount_of_crypto_trunks = 23.511

Trait_rarity_percentage = [
    List_of_Traits_in_all_NFTs[NFT][TRAITE]['trait_count']/Total_amount_of_crypto_trunks
    for NFT in range(len(List_of_Traits_in_all_NFTs))
    for TRAITE in range(len(List_of_Traits_in_all_NFTs[NFT]))
    ]

print(len(Trait_rarity_percentage))
print(Trait_rarity_percentage[0:5])
# Out:
# 301
# [0.5529326698141296, 117.30679256518226, 63.84245672238527, 0.4678661052273404, 0.8931989281612862]

# %%
#NFT_IDs
# How do I create a DataFrame where all NFT_IDs match with amount of Traits?

NFT_IDs_for_each_trait = [
    List_of_50_NFTs[NFT]['token_id']
    for NFT in range(len(List_of_Traits_in_all_NFTs))
    for TRAITE in range(len(List_of_Traits_in_all_NFTs[NFT]))
    ]

print(len(NFT_IDs_for_each_trait))
print(NFT_IDs_for_each_trait[0:10])
# Out:
# 301
# ['210', '210', '210', '210', '210', '733', '733', '733', '733', '733']

# %%
#Trait_rarity_score
# How to calculate a rarity_score for every trait?
Trait_rarity_score = [
    1/(List_of_Traits_in_all_NFTs[NFT][TRAITE]['trait_count']/Total_amount_of_crypto_trunks)
    for NFT in range(len(List_of_Traits_in_all_NFTs))
    for TRAITE in range(len(List_of_Traits_in_all_NFTs[NFT]))
    ]

print(len(Trait_rarity_score))
print(Trait_rarity_score[0:4])
# Out:
# 301
# [1.8085384615384614, 0.008524655547498186, 0.015663557628247834, 2.137363636363636]

# %% [markdown]
# 2. Create DataSet and display it in a DataFrame

# %%
Total_amount_of_crypto_trunks = 23511 

data = {'NFT_IDs': NFT_IDs_for_each_trait, #Check
        'Trait_Types': Trait_types_for_NFTs, #Check 
        'Trait_Values': Trait_value_for_NFTs,#Check
        'Trait_Counts': Trait_count_for_NFTs, #Check
        'Type_Rarity_Percentages': Trait_rarity_percentage, #Check
        'Trait_Rarity_Scores': Trait_rarity_score
        #'Trait_IDs': [1,2,3,4,5,1,2,3,1,2,3,4,] #Do it with pandas
        #'Ranking_position': [16.6, 8.6, 8.6, 12.5], #Do it with pandas
       }

df = pd.DataFrame.from_dict(data)
df.head()
# Out:
#   NFT_IDs Trait_Types              Trait_Values  Trait_Counts  \
# 0     210        Type               Burning Ash            13
# 1     210         Age                     Elder          2758
# 2     210     Edition                   Genesis          1501
# 3     210     Element         Among Us – Orange            11
# 4     210         Sky  Underwater City and Road            21
#
#    Type_Rarity_Percentages  Trait_Rarity_Scores
# 0                 0.552933             1.808538
# 1               117.306793             0.008525
# 2                63.842457             0.015664
# 3                 0.467866             2.137364
# 4                 0.893199             1.119571

# %%
#Trait_IDs
df['Trait_Ids'] = df.groupby('NFT_IDs').cumcount() + 1
df
# Out:
#     NFT_IDs Trait_Types              Trait_Values  Trait_Counts  \
# 0       210        Type               Burning Ash            13
# 1       210         Age                     Elder          2758
# 2       210     Edition                   Genesis          1501
# 3       210     Element         Among Us – Orange            11
# 4       210         Sky  Underwater City and Road            21
# ..      ...         ...                       ...           ...
# 296     337        Type           Birch Treehouse            48
# 297     337  Background              Grass – Soft            88
# 298     337     Edition                   Genesis          1501
# 299     337         Age                     Adult          4225
# 300     337  Background       Deep Forest – Leafy          3744
#
#      Type_Rarity_Percentages  Trait_Rarity_Scores  Trait_Ids
# 0                   0.552933             1.808538          1
# 1                 117.306793             0.008525          2
# 2                  63.842457             0.015664          3
# 3                   0.467866             2.137364          4
# 4                   0.893199             1.119571          5
# ..                       ...                  ...        ...
# 296                 2.041598             0.489812          3
# 297                 3.742929             0.267170          4
# 298                63.842457             0.015664          5
# 299               179.703118             0.005565          6
# 300               159.244609             0.006280          7
#
# [301 rows x 7 columns]

# %%
#Sort columns
col = df.pop("Trait_Ids")
df.insert(1, col.name, col)
df
# Out:
#     NFT_IDs  Trait_Ids Trait_Types              Trait_Values  Trait_Counts  \
# 0       210          1        Type               Burning Ash            13
# 1       210          2         Age                     Elder          2758
# 2       210          3     Edition                   Genesis          1501
# 3       210          4     Element         Among Us – Orange            11
# 4       210          5         Sky  Underwater City and Road            21
# ..      ...        ...         ...                       ...           ...
# 296     337          3        Type           Birch Treehouse            48
# 297     337          4  Background              Grass – Soft            88
# 298     337          5     Edition                   Genesis          1501
# 299     337          6         Age                     Adult          4225
# 300     337          7  Background       Deep Forest – Leafy          3744
#
#      Type_Rarity_Percentages  Trait_Rarity_Scores
# 0                   0.552933             1.808538
# 1                 117.306793             0.008525
# 2                  63.842457             0.015664
# 3                   0.467866             2.137364
# 4                   0.893199             1.119571
# ..                       ...                  ...
# 296                 2.041598             0.489812
# 297                 3.742929             0.267170
# 298                63.842457             0.015664
# 299               179.703118             0.005565
# 300               159.244609             0.006280
#
# [301 rows x 7 columns]

# %%
df.set_index('NFT_IDs')
# Out:
#          Trait_Ids Trait_Types              Trait_Values  Trait_Counts  \
# NFT_IDs
# 210              1        Type               Burning Ash            13
# 210              2         Age                     Elder          2758
# 210              3     Edition                   Genesis          1501
# 210              4     Element         Among Us – Orange            11
# 210              5         Sky  Underwater City and Road            21
# ...            ...         ...                       ...           ...
# 337              3        Type           Birch Treehouse            48
# 337              4  Background              Grass – Soft            88
# 337              5     Edition                   Genesis          1501
# 337              6         Age                     Adult          4225
# 337              7  Background       Deep Forest – Leafy          3744
#
#          Type_Rarity_Percentages  Trait_Rarity_Scores
# NFT_IDs
# 210                     0.552933             1.808538
# 210                   117.306793             0.008525
# 210                    63.842457             0.015664
# 210                     0.467866             2.137364
# 210                     0.893199             1.119571
# ...                          ...                  ...
# 337                     2.041598             0.489812
# 337                     3.742929             0.267170
# 337                    63.842457             0.015664
# 337                   179.703118             0.005565
# 337                   159.244609             0.006280
#
# [301 rows x 6 columns]

# %%
df.to_json(r'/Users/renesalmon/code/reneSalmon/NFT_Rarity_Scoring_API/NFT_traits.json', orient='records')
f = open('/Users/renesalmon/code/reneSalmon/NFT_Rarity_Scoring_API/NFT_traits.json')
NFT_traits_data = json.load(f)
NFT_traits_data
# Out:
# [{'NFT_IDs': '210',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Burning Ash',
#   'Trait_Counts': 13,
#   'Type_Rarity_Percentages': 0.5529326698,
#   'Trait_Rarity_Scores': 1.8085384615},
#  {'NFT_IDs': '210',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Elder',
#   'Trait_Counts': 2758,
#   'Type_Rarity_Percentages': 117.3067925652,
#   'Trait_Rarity_Scores': 0.0085246555},
#  {'NFT_IDs': '210',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '210',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Among Us – Orange',
#   'Trait_Counts': 11,
#   'Type_Rarity_Percentages': 0.4678661052,
#   'Trait_Rarity_Scores': 2.1373636364},
#  {'NFT_IDs': '210',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Underwater City and Road',
#   'Trait_Counts': 21,
#   'Type_Rarity_Percentages': 0.8931989282,
#   'Trait_Rarity_Scores': 1.1195714286},
#  {'NFT_IDs': '733',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Ancient',
#   'Trait_Counts': 893,
#   'Type_Rarity_Percentages': 37.982221088,
#   'Trait_Rarity_Scores': 0.0263281075},
#  {'NFT_IDs': '733',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Urban – Town',
#   'Trait_Counts': 1526,
#   'Type_Rarity_Percentages': 64.9057887797,
#   'Trait_Rarity_Scores': 0.0154069463},
#  {'NFT_IDs': '733',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Grass – Soft',
#   'Trait_Counts': 88,
#   'Type_Rarity_Percentages': 3.7429288418,
#   'Trait_Rarity_Scores': 0.2671704545},
#  {'NFT_IDs': '733',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '733',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Golden Birch',
#   'Trait_Counts': 58,
#   'Type_Rarity_Percentages': 2.466930373,
#   'Trait_Rarity_Scores': 0.405362069},
#  {'NFT_IDs': '733',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Dead Bear',
#   'Trait_Counts': 52,
#   'Type_Rarity_Percentages': 2.2117306793,
#   'Trait_Rarity_Scores': 0.4521346154},
#  {'NFT_IDs': '733',
#   'Trait_Ids': 7,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Volcano',
#   'Trait_Counts': 50,
#   'Type_Rarity_Percentages': 2.1266641147,
#   'Trait_Rarity_Scores': 0.47022},
#  {'NFT_IDs': '1256',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Hills – Rolling',
#   'Trait_Counts': 100,
#   'Type_Rarity_Percentages': 4.2533282293,
#   'Trait_Rarity_Scores': 0.23511},
#  {'NFT_IDs': '1256',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Elder',
#   'Trait_Counts': 2758,
#   'Type_Rarity_Percentages': 117.3067925652,
#   'Trait_Rarity_Scores': 0.0085246555},
#  {'NFT_IDs': '1256',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '1256',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Space',
#   'Trait_Counts': 51,
#   'Type_Rarity_Percentages': 2.169197397,
#   'Trait_Rarity_Scores': 0.461},
#  {'NFT_IDs': '1256',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Among Us – Red',
#   'Trait_Counts': 10,
#   'Type_Rarity_Percentages': 0.4253328229,
#   'Trait_Rarity_Scores': 2.3511},
#  {'NFT_IDs': '1256',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Clouds',
#   'Trait_Counts': 100,
#   'Type_Rarity_Percentages': 4.2533282293,
#   'Trait_Rarity_Scores': 0.23511},
#  {'NFT_IDs': '1256',
#   'Trait_Ids': 7,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Spruce Treehouse',
#   'Trait_Counts': 47,
#   'Type_Rarity_Percentages': 1.9990642678,
#   'Trait_Rarity_Scores': 0.5002340426},
#  {'NFT_IDs': '279',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Young',
#   'Trait_Counts': 3327,
#   'Type_Rarity_Percentages': 141.5082301901,
#   'Trait_Rarity_Scores': 0.0070667268},
#  {'NFT_IDs': '279',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Grass – Soft',
#   'Trait_Counts': 88,
#   'Type_Rarity_Percentages': 3.7429288418,
#   'Trait_Rarity_Scores': 0.2671704545},
#  {'NFT_IDs': '279',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '279',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Oak Treehouse',
#   'Trait_Counts': 51,
#   'Type_Rarity_Percentages': 2.169197397,
#   'Trait_Rarity_Scores': 0.461},
#  {'NFT_IDs': '279',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Night',
#   'Trait_Counts': 871,
#   'Type_Rarity_Percentages': 37.0464888775,
#   'Trait_Rarity_Scores': 0.0269931114},
#  {'NFT_IDs': '279',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Forest – Leafy',
#   'Trait_Counts': 3772,
#   'Type_Rarity_Percentages': 160.4355408107,
#   'Trait_Rarity_Scores': 0.0062330329},
#  {'NFT_IDs': '802',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Young',
#   'Trait_Counts': 3327,
#   'Type_Rarity_Percentages': 141.5082301901,
#   'Trait_Rarity_Scores': 0.0070667268},
#  {'NFT_IDs': '802',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '802',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Shooting Star',
#   'Trait_Counts': 106,
#   'Type_Rarity_Percentages': 4.5085279231,
#   'Trait_Rarity_Scores': 0.2218018868},
#  {'NFT_IDs': '802',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Clear Blue',
#   'Trait_Counts': 51,
#   'Type_Rarity_Percentages': 2.169197397,
#   'Trait_Rarity_Scores': 0.461},
#  {'NFT_IDs': '802',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Clouds',
#   'Trait_Counts': 100,
#   'Type_Rarity_Percentages': 4.2533282293,
#   'Trait_Rarity_Scores': 0.23511},
#  {'NFT_IDs': '802',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Ash Treehouse',
#   'Trait_Counts': 50,
#   'Type_Rarity_Percentages': 2.1266641147,
#   'Trait_Rarity_Scores': 0.47022},
#  {'NFT_IDs': '802',
#   'Trait_Ids': 7,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Mountains – Highlands',
#   'Trait_Counts': 3169,
#   'Type_Rarity_Percentages': 134.7879715878,
#   'Trait_Rarity_Scores': 0.0074190596},
#  {'NFT_IDs': '802',
#   'Trait_Ids': 8,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Ghost',
#   'Trait_Counts': 431,
#   'Type_Rarity_Percentages': 18.3318446685,
#   'Trait_Rarity_Scores': 0.054549884},
#  {'NFT_IDs': '802',
#   'Trait_Ids': 9,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Forest – Leafy',
#   'Trait_Counts': 3772,
#   'Type_Rarity_Percentages': 160.4355408107,
#   'Trait_Rarity_Scores': 0.0062330329},
#  {'NFT_IDs': '1325',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Golden Birds in Flight',
#   'Trait_Counts': 433,
#   'Type_Rarity_Percentages': 18.416911233,
#   'Trait_Rarity_Scores': 0.0542979215},
#  {'NFT_IDs': '1325',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Young',
#   'Trait_Counts': 3327,
#   'Type_Rarity_Percentages': 141.5082301901,
#   'Trait_Rarity_Scores': 0.0070667268},
#  {'NFT_IDs': '1325',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '1325',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Clouds',
#   'Trait_Counts': 100,
#   'Type_Rarity_Percentages': 4.2533282293,
#   'Trait_Rarity_Scores': 0.23511},
#  {'NFT_IDs': '1325',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Spruce Treehouse',
#   'Trait_Counts': 47,
#   'Type_Rarity_Percentages': 1.9990642678,
#   'Trait_Rarity_Scores': 0.5002340426},
#  {'NFT_IDs': '1325',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Night',
#   'Trait_Counts': 871,
#   'Type_Rarity_Percentages': 37.0464888775,
#   'Trait_Rarity_Scores': 0.0269931114},
#  {'NFT_IDs': '348',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Maple Treehouse',
#   'Trait_Counts': 47,
#   'Type_Rarity_Percentages': 1.9990642678,
#   'Trait_Rarity_Scores': 0.5002340426},
#  {'NFT_IDs': '348',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Elder',
#   'Trait_Counts': 2758,
#   'Type_Rarity_Percentages': 117.3067925652,
#   'Trait_Rarity_Scores': 0.0085246555},
#  {'NFT_IDs': '348',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '348',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Volcano with Town and Savanah Grass',
#   'Trait_Counts': 31,
#   'Type_Rarity_Percentages': 1.3185317511,
#   'Trait_Rarity_Scores': 0.7584193548},
#  {'NFT_IDs': '348',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Golden Hearts',
#   'Trait_Counts': 140,
#   'Type_Rarity_Percentages': 5.9546595211,
#   'Trait_Rarity_Scores': 0.1679357143},
#  {'NFT_IDs': '871',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Golden Gravestone',
#   'Trait_Counts': 260,
#   'Type_Rarity_Percentages': 11.0586533963,
#   'Trait_Rarity_Scores': 0.0904269231},
#  {'NFT_IDs': '871',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Elder',
#   'Trait_Counts': 2758,
#   'Type_Rarity_Percentages': 117.3067925652,
#   'Trait_Rarity_Scores': 0.0085246555},
#  {'NFT_IDs': '871',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '871',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Beach and Desert with Oasis',
#   'Trait_Counts': 20,
#   'Type_Rarity_Percentages': 0.8506656459,
#   'Trait_Rarity_Scores': 1.17555},
#  {'NFT_IDs': '871',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Rainbow Spruce',
#   'Trait_Counts': 33,
#   'Type_Rarity_Percentages': 1.4035983157,
#   'Trait_Rarity_Scores': 0.7124545455},
#  {'NFT_IDs': '1394',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Cherry Empress',
#   'Trait_Counts': 76,
#   'Type_Rarity_Percentages': 3.2325294543,
#   'Trait_Rarity_Scores': 0.3093552632},
#  {'NFT_IDs': '1394',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Golden Monkey',
#   'Trait_Counts': 185,
#   'Type_Rarity_Percentages': 7.8686572243,
#   'Trait_Rarity_Scores': 0.1270864865},
#  {'NFT_IDs': '1394',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Abstract',
#   'Trait_Counts': 97,
#   'Type_Rarity_Percentages': 4.1257283825,
#   'Trait_Rarity_Scores': 0.2423814433},
#  {'NFT_IDs': '1394',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '1394',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Sapling',
#   'Trait_Counts': 2793,
#   'Type_Rarity_Percentages': 118.7954574455,
#   'Trait_Rarity_Scores': 0.0084178303},
#  {'NFT_IDs': '417',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Cloudy Sky',
#   'Trait_Counts': 55,
#   'Type_Rarity_Percentages': 2.3393305261,
#   'Trait_Rarity_Scores': 0.4274727273},
#  {'NFT_IDs': '417',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Cherry Empress',
#   'Trait_Counts': 76,
#   'Type_Rarity_Percentages': 3.2325294543,
#   'Trait_Rarity_Scores': 0.3093552632},
#  {'NFT_IDs': '417',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Elder',
#   'Trait_Counts': 2758,
#   'Type_Rarity_Percentages': 117.3067925652,
#   'Trait_Rarity_Scores': 0.0085246555},
#  {'NFT_IDs': '417',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '417',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Among Us – Red',
#   'Trait_Counts': 10,
#   'Type_Rarity_Percentages': 0.4253328229,
#   'Trait_Rarity_Scores': 2.3511},
#  {'NFT_IDs': '940',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Urban – Skyline',
#   'Trait_Counts': 1348,
#   'Type_Rarity_Percentages': 57.3348645315,
#   'Trait_Rarity_Scores': 0.0174413947},
#  {'NFT_IDs': '940',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Grass – Meadow',
#   'Trait_Counts': 3704,
#   'Type_Rarity_Percentages': 157.5432776147,
#   'Trait_Rarity_Scores': 0.0063474622},
#  {'NFT_IDs': '940',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '940',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Adult',
#   'Trait_Counts': 4225,
#   'Type_Rarity_Percentages': 179.7031176896,
#   'Trait_Rarity_Scores': 0.0055647337},
#  {'NFT_IDs': '940',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Volcano',
#   'Trait_Counts': 50,
#   'Type_Rarity_Percentages': 2.1266641147,
#   'Trait_Rarity_Scores': 0.47022},
#  {'NFT_IDs': '940',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Golden Spruce',
#   'Trait_Counts': 60,
#   'Type_Rarity_Percentages': 2.5519969376,
#   'Trait_Rarity_Scores': 0.39185},
#  {'NFT_IDs': '1463',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Golden Maple',
#   'Trait_Counts': 59,
#   'Type_Rarity_Percentages': 2.5094636553,
#   'Trait_Rarity_Scores': 0.3984915254},
#  {'NFT_IDs': '1463',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Doge',
#   'Trait_Counts': 97,
#   'Type_Rarity_Percentages': 4.1257283825,
#   'Trait_Rarity_Scores': 0.2423814433},
#  {'NFT_IDs': '1463',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Hills – Rolling',
#   'Trait_Counts': 100,
#   'Type_Rarity_Percentages': 4.2533282293,
#   'Trait_Rarity_Scores': 0.23511},
#  {'NFT_IDs': '1463',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Grass – Soft',
#   'Trait_Counts': 88,
#   'Type_Rarity_Percentages': 3.7429288418,
#   'Trait_Rarity_Scores': 0.2671704545},
#  {'NFT_IDs': '1463',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '1463',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Dusk',
#   'Trait_Counts': 534,
#   'Type_Rarity_Percentages': 22.7127727447,
#   'Trait_Rarity_Scores': 0.0440280899},
#  {'NFT_IDs': '1463',
#   'Trait_Ids': 7,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Sapling',
#   'Trait_Counts': 2793,
#   'Type_Rarity_Percentages': 118.7954574455,
#   'Trait_Rarity_Scores': 0.0084178303},
#  {'NFT_IDs': '1463',
#   'Trait_Ids': 8,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Forest – Leafy',
#   'Trait_Counts': 3772,
#   'Type_Rarity_Percentages': 160.4355408107,
#   'Trait_Rarity_Scores': 0.0062330329},
#  {'NFT_IDs': '486',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Forest – Evergreen',
#   'Trait_Counts': 3923,
#   'Type_Rarity_Percentages': 166.858066437,
#   'Trait_Rarity_Scores': 0.0059931175},
#  {'NFT_IDs': '486',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Grass – Island',
#   'Trait_Counts': 2720,
#   'Type_Rarity_Percentages': 115.690527838,
#   'Trait_Rarity_Scores': 0.00864375},
#  {'NFT_IDs': '486',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Abstract',
#   'Trait_Counts': 97,
#   'Type_Rarity_Percentages': 4.1257283825,
#   'Trait_Rarity_Scores': 0.2423814433},
#  {'NFT_IDs': '486',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '486',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Adult',
#   'Trait_Counts': 4225,
#   'Type_Rarity_Percentages': 179.7031176896,
#   'Trait_Rarity_Scores': 0.0055647337},
#  {'NFT_IDs': '486',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Mooncat Lying',
#   'Trait_Counts': 53,
#   'Type_Rarity_Percentages': 2.2542639615,
#   'Trait_Rarity_Scores': 0.4436037736},
#  {'NFT_IDs': '486',
#   'Trait_Ids': 7,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Golden Empress',
#   'Trait_Counts': 60,
#   'Type_Rarity_Percentages': 2.5519969376,
#   'Trait_Rarity_Scores': 0.39185},
#  {'NFT_IDs': '486',
#   'Trait_Ids': 8,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Mountains – Alpine',
#   'Trait_Counts': 1478,
#   'Type_Rarity_Percentages': 62.8641912296,
#   'Trait_Rarity_Scores': 0.0159073072},
#  {'NFT_IDs': '1009',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Cherry Empress',
#   'Trait_Counts': 76,
#   'Type_Rarity_Percentages': 3.2325294543,
#   'Trait_Rarity_Scores': 0.3093552632},
#  {'NFT_IDs': '1009',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Elder',
#   'Trait_Counts': 2758,
#   'Type_Rarity_Percentages': 117.3067925652,
#   'Trait_Rarity_Scores': 0.0085246555},
#  {'NFT_IDs': '1009',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '1009',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Deep Forest',
#   'Trait_Counts': 21,
#   'Type_Rarity_Percentages': 0.8931989282,
#   'Trait_Rarity_Scores': 1.1195714286},
#  {'NFT_IDs': '1009',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Cow',
#   'Trait_Counts': 49,
#   'Type_Rarity_Percentages': 2.0841308324,
#   'Trait_Rarity_Scores': 0.4798163265},
#  {'NFT_IDs': '32',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '32',
#   'Trait_Ids': 2,
#   'Trait_Types': 'property',
#   'Trait_Values': 'Master Element',
#   'Trait_Counts': 43,
#   'Type_Rarity_Percentages': 1.8289311386,
#   'Trait_Rarity_Scores': 0.5467674419},
#  {'NFT_IDs': '32',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Spruce',
#   'Trait_Counts': 1741,
#   'Type_Rarity_Percentages': 74.0504444728,
#   'Trait_Rarity_Scores': 0.0135043079},
#  {'NFT_IDs': '32',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Moon with Space Grass',
#   'Trait_Counts': 26,
#   'Type_Rarity_Percentages': 1.1058653396,
#   'Trait_Rarity_Scores': 0.9042692308},
#  {'NFT_IDs': '32',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Elder',
#   'Trait_Counts': 2758,
#   'Type_Rarity_Percentages': 117.3067925652,
#   'Trait_Rarity_Scores': 0.0085246555},
#  {'NFT_IDs': '555',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Urban – Skyline',
#   'Trait_Counts': 1348,
#   'Type_Rarity_Percentages': 57.3348645315,
#   'Trait_Rarity_Scores': 0.0174413947},
#  {'NFT_IDs': '555',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Forest – Mixed',
#   'Trait_Counts': 3853,
#   'Type_Rarity_Percentages': 163.8807366764,
#   'Trait_Rarity_Scores': 0.0061019984},
#  {'NFT_IDs': '555',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Fire',
#   'Trait_Counts': 119,
#   'Type_Rarity_Percentages': 5.0614605929,
#   'Trait_Rarity_Scores': 0.1975714286},
#  {'NFT_IDs': '555',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Grass – Soft',
#   'Trait_Counts': 88,
#   'Type_Rarity_Percentages': 3.7429288418,
#   'Trait_Rarity_Scores': 0.2671704545},
#  {'NFT_IDs': '555',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '555',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Golden Birch',
#   'Trait_Counts': 58,
#   'Type_Rarity_Percentages': 2.466930373,
#   'Trait_Rarity_Scores': 0.405362069},
#  {'NFT_IDs': '555',
#   'Trait_Ids': 7,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Sapling',
#   'Trait_Counts': 2793,
#   'Type_Rarity_Percentages': 118.7954574455,
#   'Trait_Rarity_Scores': 0.0084178303},
#  {'NFT_IDs': '1078',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '1078',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Moon',
#   'Trait_Counts': 20,
#   'Type_Rarity_Percentages': 0.8506656459,
#   'Trait_Rarity_Scores': 1.17555},
#  {'NFT_IDs': '1078',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Cherry Empress',
#   'Trait_Counts': 76,
#   'Type_Rarity_Percentages': 3.2325294543,
#   'Trait_Rarity_Scores': 0.3093552632},
#  {'NFT_IDs': '1078',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Elder',
#   'Trait_Counts': 2758,
#   'Type_Rarity_Percentages': 117.3067925652,
#   'Trait_Rarity_Scores': 0.0085246555},
#  {'NFT_IDs': '101',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '101',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Animated',
#   'Trait_Values': 'Wind',
#   'Trait_Counts': 10,
#   'Type_Rarity_Percentages': 0.4253328229,
#   'Trait_Rarity_Scores': 2.3511},
#  {'NFT_IDs': '101',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Elder',
#   'Trait_Counts': 2758,
#   'Type_Rarity_Percentages': 117.3067925652,
#   'Trait_Rarity_Scores': 0.0085246555},
#  {'NFT_IDs': '101',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Oak Treehouse',
#   'Trait_Counts': 51,
#   'Type_Rarity_Percentages': 2.169197397,
#   'Trait_Rarity_Scores': 0.461},
#  {'NFT_IDs': '101',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Deep Forest with Road',
#   'Trait_Counts': 23,
#   'Type_Rarity_Percentages': 0.9782654927,
#   'Trait_Rarity_Scores': 1.0222173913},
#  {'NFT_IDs': '101',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Golden Fairy',
#   'Trait_Counts': 195,
#   'Type_Rarity_Percentages': 8.2939900472,
#   'Trait_Rarity_Scores': 0.1205692308},
#  {'NFT_IDs': '624',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Underwater',
#   'Trait_Counts': 49,
#   'Type_Rarity_Percentages': 2.0841308324,
#   'Trait_Rarity_Scores': 0.4798163265},
#  {'NFT_IDs': '624',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Elder',
#   'Trait_Counts': 2758,
#   'Type_Rarity_Percentages': 117.3067925652,
#   'Trait_Rarity_Scores': 0.0085246555},
#  {'NFT_IDs': '624',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '624',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Clouds',
#   'Trait_Counts': 100,
#   'Type_Rarity_Percentages': 4.2533282293,
#   'Trait_Rarity_Scores': 0.23511},
#  {'NFT_IDs': '624',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Ash Treehouse',
#   'Trait_Counts': 50,
#   'Type_Rarity_Percentages': 2.1266641147,
#   'Trait_Rarity_Scores': 0.47022},
#  {'NFT_IDs': '624',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Mountains – Alpine',
#   'Trait_Counts': 1478,
#   'Type_Rarity_Percentages': 62.8641912296,
#   'Trait_Rarity_Scores': 0.0159073072},
#  {'NFT_IDs': '1147',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Glitch',
#   'Trait_Counts': 99,
#   'Type_Rarity_Percentages': 4.210794947,
#   'Trait_Rarity_Scores': 0.2374848485},
#  {'NFT_IDs': '1147',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Urban – Town',
#   'Trait_Counts': 1526,
#   'Type_Rarity_Percentages': 64.9057887797,
#   'Trait_Rarity_Scores': 0.0154069463},
#  {'NFT_IDs': '1147',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Elder',
#   'Trait_Counts': 2758,
#   'Type_Rarity_Percentages': 117.3067925652,
#   'Trait_Rarity_Scores': 0.0085246555},
#  {'NFT_IDs': '1147',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '1147',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Burning Poplar',
#   'Trait_Counts': 15,
#   'Type_Rarity_Percentages': 0.6379992344,
#   'Trait_Rarity_Scores': 1.5674},
#  {'NFT_IDs': '1147',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Road – Dirt',
#   'Trait_Counts': 1832,
#   'Type_Rarity_Percentages': 77.9209731615,
#   'Trait_Rarity_Scores': 0.0128335153},
#  {'NFT_IDs': '1147',
#   'Trait_Ids': 7,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Mountains – Alpine',
#   'Trait_Counts': 1478,
#   'Type_Rarity_Percentages': 62.8641912296,
#   'Trait_Rarity_Scores': 0.0159073072},
#  {'NFT_IDs': '170',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '170',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Elder',
#   'Trait_Counts': 2758,
#   'Type_Rarity_Percentages': 117.3067925652,
#   'Trait_Rarity_Scores': 0.0085246555},
#  {'NFT_IDs': '170',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'AC',
#   'Trait_Counts': 73,
#   'Type_Rarity_Percentages': 3.1049296074,
#   'Trait_Rarity_Scores': 0.3220684932},
#  {'NFT_IDs': '170',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Beach and Sea with Urban Road',
#   'Trait_Counts': 21,
#   'Type_Rarity_Percentages': 0.8931989282,
#   'Trait_Rarity_Scores': 1.1195714286},
#  {'NFT_IDs': '693',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Underwater and Fish',
#   'Trait_Counts': 59,
#   'Type_Rarity_Percentages': 2.5094636553,
#   'Trait_Rarity_Scores': 0.3984915254},
#  {'NFT_IDs': '693',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Urban – Town',
#   'Trait_Counts': 1526,
#   'Type_Rarity_Percentages': 64.9057887797,
#   'Trait_Rarity_Scores': 0.0154069463},
#  {'NFT_IDs': '693',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Golden Monkey',
#   'Trait_Counts': 185,
#   'Type_Rarity_Percentages': 7.8686572243,
#   'Trait_Rarity_Scores': 0.1270864865},
#  {'NFT_IDs': '693',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Elder',
#   'Trait_Counts': 2758,
#   'Type_Rarity_Percentages': 117.3067925652,
#   'Trait_Rarity_Scores': 0.0085246555},
#  {'NFT_IDs': '693',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '693',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Volcano',
#   'Trait_Counts': 50,
#   'Type_Rarity_Percentages': 2.1266641147,
#   'Trait_Rarity_Scores': 0.47022},
#  {'NFT_IDs': '693',
#   'Trait_Ids': 7,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Road – Dirt',
#   'Trait_Counts': 1832,
#   'Type_Rarity_Percentages': 77.9209731615,
#   'Trait_Rarity_Scores': 0.0128335153},
#  {'NFT_IDs': '693',
#   'Trait_Ids': 8,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Golden Spruce',
#   'Trait_Counts': 60,
#   'Type_Rarity_Percentages': 2.5519969376,
#   'Trait_Rarity_Scores': 0.39185},
#  {'NFT_IDs': '1216',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Golden Oak',
#   'Trait_Counts': 62,
#   'Type_Rarity_Percentages': 2.6370635022,
#   'Trait_Rarity_Scores': 0.3792096774},
#  {'NFT_IDs': '1216',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Ancient',
#   'Trait_Counts': 893,
#   'Type_Rarity_Percentages': 37.982221088,
#   'Trait_Rarity_Scores': 0.0263281075},
#  {'NFT_IDs': '1216',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Hills – Rolling',
#   'Trait_Counts': 100,
#   'Type_Rarity_Percentages': 4.2533282293,
#   'Trait_Rarity_Scores': 0.23511},
#  {'NFT_IDs': '1216',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '1216',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Rune',
#   'Trait_Counts': 97,
#   'Type_Rarity_Percentages': 4.1257283825,
#   'Trait_Rarity_Scores': 0.2423814433},
#  {'NFT_IDs': '1216',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Night',
#   'Trait_Counts': 871,
#   'Type_Rarity_Percentages': 37.0464888775,
#   'Trait_Rarity_Scores': 0.0269931114},
#  {'NFT_IDs': '1216',
#   'Trait_Ids': 7,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Underwater – Seabed',
#   'Trait_Counts': 98,
#   'Type_Rarity_Percentages': 4.1682616648,
#   'Trait_Rarity_Scores': 0.2399081633},
#  {'NFT_IDs': '239',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Ancient',
#   'Trait_Counts': 893,
#   'Type_Rarity_Percentages': 37.982221088,
#   'Trait_Rarity_Scores': 0.0263281075},
#  {'NFT_IDs': '239',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Grass – Riverside',
#   'Trait_Counts': 2662,
#   'Type_Rarity_Percentages': 113.223597465,
#   'Trait_Rarity_Scores': 0.0088320811},
#  {'NFT_IDs': '239',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Gravestone',
#   'Trait_Counts': 266,
#   'Type_Rarity_Percentages': 11.31385309,
#   'Trait_Rarity_Scores': 0.088387218},
#  {'NFT_IDs': '239',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '239',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Spruce Treehouse',
#   'Trait_Counts': 47,
#   'Type_Rarity_Percentages': 1.9990642678,
#   'Trait_Rarity_Scores': 0.5002340426},
#  {'NFT_IDs': '239',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Night',
#   'Trait_Counts': 871,
#   'Type_Rarity_Percentages': 37.0464888775,
#   'Trait_Rarity_Scores': 0.0269931114},
#  {'NFT_IDs': '239',
#   'Trait_Ids': 7,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Deep Forest – Leafy',
#   'Trait_Counts': 3744,
#   'Type_Rarity_Percentages': 159.2446089065,
#   'Trait_Rarity_Scores': 0.0062796474},
#  {'NFT_IDs': '762',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Ancient',
#   'Trait_Counts': 893,
#   'Type_Rarity_Percentages': 37.982221088,
#   'Trait_Rarity_Scores': 0.0263281075},
#  {'NFT_IDs': '762',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Rainbow Empress',
#   'Trait_Counts': 34,
#   'Type_Rarity_Percentages': 1.446131598,
#   'Trait_Rarity_Scores': 0.6915},
#  {'NFT_IDs': '762',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Gravestone',
#   'Trait_Counts': 266,
#   'Type_Rarity_Percentages': 11.31385309,
#   'Trait_Rarity_Scores': 0.088387218},
#  {'NFT_IDs': '762',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '762',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Deep Forest with Clouds',
#   'Trait_Counts': 20,
#   'Type_Rarity_Percentages': 0.8506656459,
#   'Trait_Rarity_Scores': 1.17555},
#  {'NFT_IDs': '1285',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Grass – Meadow',
#   'Trait_Counts': 3704,
#   'Type_Rarity_Percentages': 157.5432776147,
#   'Trait_Rarity_Scores': 0.0063474622},
#  {'NFT_IDs': '1285',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Urban – Town',
#   'Trait_Counts': 1526,
#   'Type_Rarity_Percentages': 64.9057887797,
#   'Trait_Rarity_Scores': 0.0154069463},
#  {'NFT_IDs': '1285',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '1285',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Adult',
#   'Trait_Counts': 4225,
#   'Type_Rarity_Percentages': 179.7031176896,
#   'Trait_Rarity_Scores': 0.0055647337},
#  {'NFT_IDs': '1285',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Rainbow Ash',
#   'Trait_Counts': 36,
#   'Type_Rarity_Percentages': 1.5311981626,
#   'Trait_Rarity_Scores': 0.6530833333},
#  {'NFT_IDs': '1285',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Night',
#   'Trait_Counts': 871,
#   'Type_Rarity_Percentages': 37.0464888775,
#   'Trait_Rarity_Scores': 0.0269931114},
#  {'NFT_IDs': '1285',
#   'Trait_Ids': 7,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Golden Skull',
#   'Trait_Counts': 269,
#   'Type_Rarity_Percentages': 11.4414529369,
#   'Trait_Rarity_Scores': 0.087401487},
#  {'NFT_IDs': '1285',
#   'Trait_Ids': 8,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Deep Forest – Leafy',
#   'Trait_Counts': 3744,
#   'Type_Rarity_Percentages': 159.2446089065,
#   'Trait_Rarity_Scores': 0.0062796474},
#  {'NFT_IDs': '308',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Forest – Evergreen',
#   'Trait_Counts': 3923,
#   'Type_Rarity_Percentages': 166.858066437,
#   'Trait_Rarity_Scores': 0.0059931175},
#  {'NFT_IDs': '308',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Morning',
#   'Trait_Counts': 1921,
#   'Type_Rarity_Percentages': 81.7064352856,
#   'Trait_Rarity_Scores': 0.0122389381},
#  {'NFT_IDs': '308',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Elder',
#   'Trait_Counts': 2758,
#   'Type_Rarity_Percentages': 117.3067925652,
#   'Trait_Rarity_Scores': 0.0085246555},
#  {'NFT_IDs': '308',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '308',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Golden Empress',
#   'Trait_Counts': 60,
#   'Type_Rarity_Percentages': 2.5519969376,
#   'Trait_Rarity_Scores': 0.39185},
#  {'NFT_IDs': '308',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Mountain',
#   'Trait_Counts': 103,
#   'Type_Rarity_Percentages': 4.3809280762,
#   'Trait_Rarity_Scores': 0.2282621359},
#  {'NFT_IDs': '308',
#   'Trait_Ids': 7,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Mountains – Alpine',
#   'Trait_Counts': 1478,
#   'Type_Rarity_Percentages': 62.8641912296,
#   'Trait_Rarity_Scores': 0.0159073072},
#  {'NFT_IDs': '831',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Young',
#   'Trait_Counts': 3327,
#   'Type_Rarity_Percentages': 141.5082301901,
#   'Trait_Rarity_Scores': 0.0070667268},
#  {'NFT_IDs': '831',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Maple Treehouse',
#   'Trait_Counts': 47,
#   'Type_Rarity_Percentages': 1.9990642678,
#   'Trait_Rarity_Scores': 0.5002340426},
#  {'NFT_IDs': '831',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Abstract',
#   'Trait_Counts': 97,
#   'Type_Rarity_Percentages': 4.1257283825,
#   'Trait_Rarity_Scores': 0.2423814433},
#  {'NFT_IDs': '831',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '831',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Rune',
#   'Trait_Counts': 97,
#   'Type_Rarity_Percentages': 4.1257283825,
#   'Trait_Rarity_Scores': 0.2423814433},
#  {'NFT_IDs': '1354',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '1354',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Underwater Mountains',
#   'Trait_Counts': 19,
#   'Type_Rarity_Percentages': 0.8081323636,
#   'Trait_Rarity_Scores': 1.2374210526},
#  {'NFT_IDs': '1354',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Rainbow Ash',
#   'Trait_Counts': 36,
#   'Type_Rarity_Percentages': 1.5311981626,
#   'Trait_Rarity_Scores': 0.6530833333},
#  {'NFT_IDs': '1354',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Sapling',
#   'Trait_Counts': 2793,
#   'Type_Rarity_Percentages': 118.7954574455,
#   'Trait_Rarity_Scores': 0.0084178303},
#  {'NFT_IDs': '377',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Underwater City and Road',
#   'Trait_Counts': 21,
#   'Type_Rarity_Percentages': 0.8931989282,
#   'Trait_Rarity_Scores': 1.1195714286},
#  {'NFT_IDs': '377',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '377',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Rug — Classical',
#   'Trait_Counts': 9,
#   'Type_Rarity_Percentages': 0.3827995406,
#   'Trait_Rarity_Scores': 2.6123333333},
#  {'NFT_IDs': '377',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Rune',
#   'Trait_Counts': 97,
#   'Type_Rarity_Percentages': 4.1257283825,
#   'Trait_Rarity_Scores': 0.2423814433},
#  {'NFT_IDs': '900',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Road – Stone',
#   'Trait_Counts': 1907,
#   'Type_Rarity_Percentages': 81.1109693335,
#   'Trait_Rarity_Scores': 0.0123287887},
#  {'NFT_IDs': '900',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Adult',
#   'Trait_Counts': 4225,
#   'Type_Rarity_Percentages': 179.7031176896,
#   'Trait_Rarity_Scores': 0.0055647337},
#  {'NFT_IDs': '900',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '900',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Oak Treehouse',
#   'Trait_Counts': 51,
#   'Type_Rarity_Percentages': 2.169197397,
#   'Trait_Rarity_Scores': 0.461},
#  {'NFT_IDs': '900',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Color – Pink',
#   'Trait_Counts': 9,
#   'Type_Rarity_Percentages': 0.3827995406,
#   'Trait_Rarity_Scores': 2.6123333333},
#  {'NFT_IDs': '900',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Mountains – Alpine',
#   'Trait_Counts': 1478,
#   'Type_Rarity_Percentages': 62.8641912296,
#   'Trait_Rarity_Scores': 0.0159073072},
#  {'NFT_IDs': '1423',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Elder',
#   'Trait_Counts': 2758,
#   'Type_Rarity_Percentages': 117.3067925652,
#   'Trait_Rarity_Scores': 0.0085246555},
#  {'NFT_IDs': '1423',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '1423',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Golden Ghost',
#   'Trait_Counts': 212,
#   'Type_Rarity_Percentages': 9.0170558462,
#   'Trait_Rarity_Scores': 0.1109009434},
#  {'NFT_IDs': '1423',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Poplar Treehouse',
#   'Trait_Counts': 49,
#   'Type_Rarity_Percentages': 2.0841308324,
#   'Trait_Rarity_Scores': 0.4798163265},
#  {'NFT_IDs': '1423',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Beach and Sea with Meadow Grass',
#   'Trait_Counts': 24,
#   'Type_Rarity_Percentages': 1.020798775,
#   'Trait_Rarity_Scores': 0.979625},
#  {'NFT_IDs': '446',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Glitch',
#   'Trait_Counts': 99,
#   'Type_Rarity_Percentages': 4.210794947,
#   'Trait_Rarity_Scores': 0.2374848485},
#  {'NFT_IDs': '446',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Road – Stone',
#   'Trait_Counts': 1907,
#   'Type_Rarity_Percentages': 81.1109693335,
#   'Trait_Rarity_Scores': 0.0123287887},
#  {'NFT_IDs': '446',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Elder',
#   'Trait_Counts': 2758,
#   'Type_Rarity_Percentages': 117.3067925652,
#   'Trait_Rarity_Scores': 0.0085246555},
#  {'NFT_IDs': '446',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '446',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Burning Oak',
#   'Trait_Counts': 15,
#   'Type_Rarity_Percentages': 0.6379992344,
#   'Trait_Rarity_Scores': 1.5674},
#  {'NFT_IDs': '446',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Mountains – Alpine',
#   'Trait_Counts': 1478,
#   'Type_Rarity_Percentages': 62.8641912296,
#   'Trait_Rarity_Scores': 0.0159073072},
#  {'NFT_IDs': '969',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Underwater',
#   'Trait_Counts': 49,
#   'Type_Rarity_Percentages': 2.0841308324,
#   'Trait_Rarity_Scores': 0.4798163265},
#  {'NFT_IDs': '969',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Forest – Mixed',
#   'Trait_Counts': 3853,
#   'Type_Rarity_Percentages': 163.8807366764,
#   'Trait_Rarity_Scores': 0.0061019984},
#  {'NFT_IDs': '969',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Ancient',
#   'Trait_Counts': 893,
#   'Type_Rarity_Percentages': 37.982221088,
#   'Trait_Rarity_Scores': 0.0263281075},
#  {'NFT_IDs': '969',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Doge',
#   'Trait_Counts': 97,
#   'Type_Rarity_Percentages': 4.1257283825,
#   'Trait_Rarity_Scores': 0.2423814433},
#  {'NFT_IDs': '969',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Hills – Rolling',
#   'Trait_Counts': 100,
#   'Type_Rarity_Percentages': 4.2533282293,
#   'Trait_Rarity_Scores': 0.23511},
#  {'NFT_IDs': '969',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '969',
#   'Trait_Ids': 7,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Rainbow Poplar',
#   'Trait_Counts': 34,
#   'Type_Rarity_Percentages': 1.446131598,
#   'Trait_Rarity_Scores': 0.6915},
#  {'NFT_IDs': '969',
#   'Trait_Ids': 8,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Shooting Star',
#   'Trait_Counts': 106,
#   'Type_Rarity_Percentages': 4.5085279231,
#   'Trait_Rarity_Scores': 0.2218018868},
#  {'NFT_IDs': '969',
#   'Trait_Ids': 9,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Mountain',
#   'Trait_Counts': 103,
#   'Type_Rarity_Percentages': 4.3809280762,
#   'Trait_Rarity_Scores': 0.2282621359},
#  {'NFT_IDs': '1492',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Urban – Skyline',
#   'Trait_Counts': 1348,
#   'Type_Rarity_Percentages': 57.3348645315,
#   'Trait_Rarity_Scores': 0.0174413947},
#  {'NFT_IDs': '1492',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Young',
#   'Trait_Counts': 3327,
#   'Type_Rarity_Percentages': 141.5082301901,
#   'Trait_Rarity_Scores': 0.0070667268},
#  {'NFT_IDs': '1492',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Doge',
#   'Trait_Counts': 97,
#   'Type_Rarity_Percentages': 4.1257283825,
#   'Trait_Rarity_Scores': 0.2423814433},
#  {'NFT_IDs': '1492',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '1492',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Golden Poplar',
#   'Trait_Counts': 59,
#   'Type_Rarity_Percentages': 2.5094636553,
#   'Trait_Rarity_Scores': 0.3984915254},
#  {'NFT_IDs': '1492',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Volcano',
#   'Trait_Counts': 50,
#   'Type_Rarity_Percentages': 2.1266641147,
#   'Trait_Rarity_Scores': 0.47022},
#  {'NFT_IDs': '1492',
#   'Trait_Ids': 7,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Mountain',
#   'Trait_Counts': 103,
#   'Type_Rarity_Percentages': 4.3809280762,
#   'Trait_Rarity_Scores': 0.2282621359},
#  {'NFT_IDs': '515',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '515',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Deep Space',
#   'Trait_Counts': 101,
#   'Type_Rarity_Percentages': 4.2958615116,
#   'Trait_Rarity_Scores': 0.2327821782},
#  {'NFT_IDs': '515',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Rainbow Maple',
#   'Trait_Counts': 32,
#   'Type_Rarity_Percentages': 1.3610650334,
#   'Trait_Rarity_Scores': 0.73471875},
#  {'NFT_IDs': '515',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Elder',
#   'Trait_Counts': 2758,
#   'Type_Rarity_Percentages': 117.3067925652,
#   'Trait_Rarity_Scores': 0.0085246555},
#  {'NFT_IDs': '1038',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Underwater and Fish',
#   'Trait_Counts': 59,
#   'Type_Rarity_Percentages': 2.5094636553,
#   'Trait_Rarity_Scores': 0.3984915254},
#  {'NFT_IDs': '1038',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Elder',
#   'Trait_Counts': 2758,
#   'Type_Rarity_Percentages': 117.3067925652,
#   'Trait_Rarity_Scores': 0.0085246555},
#  {'NFT_IDs': '1038',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Grass – Soft',
#   'Trait_Counts': 88,
#   'Type_Rarity_Percentages': 3.7429288418,
#   'Trait_Rarity_Scores': 0.2671704545},
#  {'NFT_IDs': '1038',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '1038',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Golden Empress',
#   'Trait_Counts': 60,
#   'Type_Rarity_Percentages': 2.5519969376,
#   'Trait_Rarity_Scores': 0.39185},
#  {'NFT_IDs': '1038',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Dusk',
#   'Trait_Counts': 534,
#   'Type_Rarity_Percentages': 22.7127727447,
#   'Trait_Rarity_Scores': 0.0440280899},
#  {'NFT_IDs': '1038',
#   'Trait_Ids': 7,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Ghost',
#   'Trait_Counts': 431,
#   'Type_Rarity_Percentages': 18.3318446685,
#   'Trait_Rarity_Scores': 0.054549884},
#  {'NFT_IDs': '61',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '61',
#   'Trait_Ids': 2,
#   'Trait_Types': 'property',
#   'Trait_Values': 'Master Element',
#   'Trait_Counts': 43,
#   'Type_Rarity_Percentages': 1.8289311386,
#   'Trait_Rarity_Scores': 0.5467674419},
#  {'NFT_IDs': '61',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Spruce',
#   'Trait_Counts': 1741,
#   'Type_Rarity_Percentages': 74.0504444728,
#   'Trait_Rarity_Scores': 0.0135043079},
#  {'NFT_IDs': '61',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Young',
#   'Trait_Counts': 3327,
#   'Type_Rarity_Percentages': 141.5082301901,
#   'Trait_Rarity_Scores': 0.0070667268},
#  {'NFT_IDs': '61',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Deep Space',
#   'Trait_Counts': 101,
#   'Type_Rarity_Percentages': 4.2958615116,
#   'Trait_Rarity_Scores': 0.2327821782},
#  {'NFT_IDs': '584',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Young',
#   'Trait_Counts': 3327,
#   'Type_Rarity_Percentages': 141.5082301901,
#   'Trait_Rarity_Scores': 0.0070667268},
#  {'NFT_IDs': '584',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '584',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Rune',
#   'Trait_Counts': 97,
#   'Type_Rarity_Percentages': 4.1257283825,
#   'Trait_Rarity_Scores': 0.2423814433},
#  {'NFT_IDs': '584',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Beach and Desert',
#   'Trait_Counts': 26,
#   'Type_Rarity_Percentages': 1.1058653396,
#   'Trait_Rarity_Scores': 0.9042692308},
#  {'NFT_IDs': '584',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'AC',
#   'Trait_Counts': 73,
#   'Type_Rarity_Percentages': 3.1049296074,
#   'Trait_Rarity_Scores': 0.3220684932},
#  {'NFT_IDs': '1107',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Urban – Skyline',
#   'Trait_Counts': 1348,
#   'Type_Rarity_Percentages': 57.3348645315,
#   'Trait_Rarity_Scores': 0.0174413947},
#  {'NFT_IDs': '1107',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Young',
#   'Trait_Counts': 3327,
#   'Type_Rarity_Percentages': 141.5082301901,
#   'Trait_Rarity_Scores': 0.0070667268},
#  {'NFT_IDs': '1107',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Morning',
#   'Trait_Counts': 1921,
#   'Type_Rarity_Percentages': 81.7064352856,
#   'Trait_Rarity_Scores': 0.0122389381},
#  {'NFT_IDs': '1107',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Gravestone',
#   'Trait_Counts': 266,
#   'Type_Rarity_Percentages': 11.31385309,
#   'Trait_Rarity_Scores': 0.088387218},
#  {'NFT_IDs': '1107',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '1107',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Rainbow Maple',
#   'Trait_Counts': 32,
#   'Type_Rarity_Percentages': 1.3610650334,
#   'Trait_Rarity_Scores': 0.73471875},
#  {'NFT_IDs': '1107',
#   'Trait_Ids': 7,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Underwater – Seabed',
#   'Trait_Counts': 98,
#   'Type_Rarity_Percentages': 4.1682616648,
#   'Trait_Rarity_Scores': 0.2399081633},
#  {'NFT_IDs': '130',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Golden Spruce',
#   'Trait_Counts': 60,
#   'Type_Rarity_Percentages': 2.5519969376,
#   'Trait_Rarity_Scores': 0.39185},
#  {'NFT_IDs': '130',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Underwater',
#   'Trait_Counts': 49,
#   'Type_Rarity_Percentages': 2.0841308324,
#   'Trait_Rarity_Scores': 0.4798163265},
#  {'NFT_IDs': '130',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Golden Stars',
#   'Trait_Counts': 471,
#   'Type_Rarity_Percentages': 20.0331759602,
#   'Trait_Rarity_Scores': 0.0499171975},
#  {'NFT_IDs': '130',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '130',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Clouds',
#   'Trait_Counts': 100,
#   'Type_Rarity_Percentages': 4.2533282293,
#   'Trait_Rarity_Scores': 0.23511},
#  {'NFT_IDs': '130',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Sapling',
#   'Trait_Counts': 2793,
#   'Type_Rarity_Percentages': 118.7954574455,
#   'Trait_Rarity_Scores': 0.0084178303},
#  {'NFT_IDs': '130',
#   'Trait_Ids': 7,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Mountains – Alpine',
#   'Trait_Counts': 1478,
#   'Type_Rarity_Percentages': 62.8641912296,
#   'Trait_Rarity_Scores': 0.0159073072},
#  {'NFT_IDs': '653',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Forest – Evergreen',
#   'Trait_Counts': 3923,
#   'Type_Rarity_Percentages': 166.858066437,
#   'Trait_Rarity_Scores': 0.0059931175},
#  {'NFT_IDs': '653',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Abstract',
#   'Trait_Counts': 97,
#   'Type_Rarity_Percentages': 4.1257283825,
#   'Trait_Rarity_Scores': 0.2423814433},
#  {'NFT_IDs': '653',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '653',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Adult',
#   'Trait_Counts': 4225,
#   'Type_Rarity_Percentages': 179.7031176896,
#   'Trait_Rarity_Scores': 0.0055647337},
#  {'NFT_IDs': '653',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Grass – Savanah',
#   'Trait_Counts': 63,
#   'Type_Rarity_Percentages': 2.6795967845,
#   'Trait_Rarity_Scores': 0.3731904762},
#  {'NFT_IDs': '653',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Ash Treehouse',
#   'Trait_Counts': 50,
#   'Type_Rarity_Percentages': 2.1266641147,
#   'Trait_Rarity_Scores': 0.47022},
#  {'NFT_IDs': '653',
#   'Trait_Ids': 7,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Skull',
#   'Trait_Counts': 516,
#   'Type_Rarity_Percentages': 21.9471736634,
#   'Trait_Rarity_Scores': 0.0455639535},
#  {'NFT_IDs': '1176',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Golden Ash',
#   'Trait_Counts': 61,
#   'Type_Rarity_Percentages': 2.5945302199,
#   'Trait_Rarity_Scores': 0.3854262295},
#  {'NFT_IDs': '1176',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '1176',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Clear Blue',
#   'Trait_Counts': 51,
#   'Type_Rarity_Percentages': 2.169197397,
#   'Trait_Rarity_Scores': 0.461},
#  {'NFT_IDs': '1176',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Sapling',
#   'Trait_Counts': 2793,
#   'Type_Rarity_Percentages': 118.7954574455,
#   'Trait_Rarity_Scores': 0.0084178303},
#  {'NFT_IDs': '1176',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Underwater – Seabed',
#   'Trait_Counts': 98,
#   'Type_Rarity_Percentages': 4.1682616648,
#   'Trait_Rarity_Scores': 0.2399081633},
#  {'NFT_IDs': '1176',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Mountains – Alpine',
#   'Trait_Counts': 1478,
#   'Type_Rarity_Percentages': 62.8641912296,
#   'Trait_Rarity_Scores': 0.0159073072},
#  {'NFT_IDs': '199',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Burning Birch',
#   'Trait_Counts': 14,
#   'Type_Rarity_Percentages': 0.5954659521,
#   'Trait_Rarity_Scores': 1.6793571429},
#  {'NFT_IDs': '199',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Elder',
#   'Trait_Counts': 2758,
#   'Type_Rarity_Percentages': 117.3067925652,
#   'Trait_Rarity_Scores': 0.0085246555},
#  {'NFT_IDs': '199',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '199',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Mooncat Lying',
#   'Trait_Counts': 53,
#   'Type_Rarity_Percentages': 2.2542639615,
#   'Trait_Rarity_Scores': 0.4436037736},
#  {'NFT_IDs': '199',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Beach and Desert with Savanah Grass',
#   'Trait_Counts': 17,
#   'Type_Rarity_Percentages': 0.723065799,
#   'Trait_Rarity_Scores': 1.383},
#  {'NFT_IDs': '722',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Golden Butterflies',
#   'Trait_Counts': 240,
#   'Type_Rarity_Percentages': 10.2079877504,
#   'Trait_Rarity_Scores': 0.0979625},
#  {'NFT_IDs': '722',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Abstract',
#   'Trait_Counts': 97,
#   'Type_Rarity_Percentages': 4.1257283825,
#   'Trait_Rarity_Scores': 0.2423814433},
#  {'NFT_IDs': '722',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Adult',
#   'Trait_Counts': 4225,
#   'Type_Rarity_Percentages': 179.7031176896,
#   'Trait_Rarity_Scores': 0.0055647337},
#  {'NFT_IDs': '722',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '722',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Golden Spruce',
#   'Trait_Counts': 60,
#   'Type_Rarity_Percentages': 2.5519969376,
#   'Trait_Rarity_Scores': 0.39185},
#  {'NFT_IDs': '1245',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Ancient',
#   'Trait_Counts': 893,
#   'Type_Rarity_Percentages': 37.982221088,
#   'Trait_Rarity_Scores': 0.0263281075},
#  {'NFT_IDs': '1245',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '1245',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Shooting Star',
#   'Trait_Counts': 106,
#   'Type_Rarity_Percentages': 4.5085279231,
#   'Trait_Rarity_Scores': 0.2218018868},
#  {'NFT_IDs': '1245',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Snowy Spruce',
#   'Trait_Counts': 74,
#   'Type_Rarity_Percentages': 3.1474628897,
#   'Trait_Rarity_Scores': 0.3177162162},
#  {'NFT_IDs': '1245',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Rolling Hills',
#   'Trait_Counts': 50,
#   'Type_Rarity_Percentages': 2.1266641147,
#   'Trait_Rarity_Scores': 0.47022},
#  {'NFT_IDs': '268',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Abstract',
#   'Trait_Counts': 97,
#   'Type_Rarity_Percentages': 4.1257283825,
#   'Trait_Rarity_Scores': 0.2423814433},
#  {'NFT_IDs': '268',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Element',
#   'Trait_Values': 'Gravestone',
#   'Trait_Counts': 266,
#   'Type_Rarity_Percentages': 11.31385309,
#   'Trait_Rarity_Scores': 0.088387218},
#  {'NFT_IDs': '268',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Adult',
#   'Trait_Counts': 4225,
#   'Type_Rarity_Percentages': 179.7031176896,
#   'Trait_Rarity_Scores': 0.0055647337},
#  {'NFT_IDs': '268',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '268',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Rainbow Ash',
#   'Trait_Counts': 36,
#   'Type_Rarity_Percentages': 1.5311981626,
#   'Trait_Rarity_Scores': 0.6530833333},
#  {'NFT_IDs': '791',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Urban – Town',
#   'Trait_Counts': 1526,
#   'Type_Rarity_Percentages': 64.9057887797,
#   'Trait_Rarity_Scores': 0.0154069463},
#  {'NFT_IDs': '791',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Grass – Riverside',
#   'Trait_Counts': 2662,
#   'Type_Rarity_Percentages': 113.223597465,
#   'Trait_Rarity_Scores': 0.0088320811},
#  {'NFT_IDs': '791',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Space',
#   'Trait_Counts': 51,
#   'Type_Rarity_Percentages': 2.169197397,
#   'Trait_Rarity_Scores': 0.461},
#  {'NFT_IDs': '791',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Golden Ash',
#   'Trait_Counts': 61,
#   'Type_Rarity_Percentages': 2.5945302199,
#   'Trait_Rarity_Scores': 0.3854262295},
#  {'NFT_IDs': '791',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '791',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Sapling',
#   'Trait_Counts': 2793,
#   'Type_Rarity_Percentages': 118.7954574455,
#   'Trait_Rarity_Scores': 0.0084178303},
#  {'NFT_IDs': '1314',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Ancient',
#   'Trait_Counts': 893,
#   'Type_Rarity_Percentages': 37.982221088,
#   'Trait_Rarity_Scores': 0.0263281075},
#  {'NFT_IDs': '1314',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Urban – Town',
#   'Trait_Counts': 1526,
#   'Type_Rarity_Percentages': 64.9057887797,
#   'Trait_Rarity_Scores': 0.0154069463},
#  {'NFT_IDs': '1314',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Grass – Riverside',
#   'Trait_Counts': 2662,
#   'Type_Rarity_Percentages': 113.223597465,
#   'Trait_Rarity_Scores': 0.0088320811},
#  {'NFT_IDs': '1314',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '1314',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Poplar Treehouse',
#   'Trait_Counts': 49,
#   'Type_Rarity_Percentages': 2.0841308324,
#   'Trait_Rarity_Scores': 0.4798163265},
#  {'NFT_IDs': '1314',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Dusk',
#   'Trait_Counts': 534,
#   'Type_Rarity_Percentages': 22.7127727447,
#   'Trait_Rarity_Scores': 0.0440280899},
#  {'NFT_IDs': '337',
#   'Trait_Ids': 1,
#   'Trait_Types': 'Sky',
#   'Trait_Values': 'Trees – Deep Forest',
#   'Trait_Counts': 53,
#   'Type_Rarity_Percentages': 2.2542639615,
#   'Trait_Rarity_Scores': 0.4436037736},
#  {'NFT_IDs': '337',
#   'Trait_Ids': 2,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Forest – Mixed',
#   'Trait_Counts': 3853,
#   'Type_Rarity_Percentages': 163.8807366764,
#   'Trait_Rarity_Scores': 0.0061019984},
#  {'NFT_IDs': '337',
#   'Trait_Ids': 3,
#   'Trait_Types': 'Type',
#   'Trait_Values': 'Birch Treehouse',
#   'Trait_Counts': 48,
#   'Type_Rarity_Percentages': 2.0415975501,
#   'Trait_Rarity_Scores': 0.4898125},
#  {'NFT_IDs': '337',
#   'Trait_Ids': 4,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Grass – Soft',
#   'Trait_Counts': 88,
#   'Type_Rarity_Percentages': 3.7429288418,
#   'Trait_Rarity_Scores': 0.2671704545},
#  {'NFT_IDs': '337',
#   'Trait_Ids': 5,
#   'Trait_Types': 'Edition',
#   'Trait_Values': 'Genesis',
#   'Trait_Counts': 1501,
#   'Type_Rarity_Percentages': 63.8424567224,
#   'Trait_Rarity_Scores': 0.0156635576},
#  {'NFT_IDs': '337',
#   'Trait_Ids': 6,
#   'Trait_Types': 'Age',
#   'Trait_Values': 'Adult',
#   'Trait_Counts': 4225,
#   'Type_Rarity_Percentages': 179.7031176896,
#   'Trait_Rarity_Scores': 0.0055647337},
#  {'NFT_IDs': '337',
#   'Trait_Ids': 7,
#   'Trait_Types': 'Background',
#   'Trait_Values': 'Deep Forest – Leafy',
#   'Trait_Counts': 3744,
#   'Type_Rarity_Percentages': 159.2446089065,
#   'Trait_Rarity_Scores': 0.0062796474}]

# %% [markdown]
# # Goal 02: NFT_rarity_score

# %%
#NFT_rarity_Score

NFT_rarity_score = []

count_of_traits_per_NFT = collections.Counter(NFT_IDs_for_each_trait)
count_of_traits_per_NFT

print(len(count_of_traits_per_NFT))
print(count_of_traits_per_NFT)
# Out:
# 50
# Counter({'802': 9, '969': 9, '1463': 8, '486': 8, '693': 8, '1285': 8, '733': 7, '1256': 7, '555': 7, '1147': 7, '1216': 7, '239': 7, '308': 7, '1492': 7, '1038': 7, '1107': 7, '130': 7, '653': 7, '337': 7, '279': 6, '1325': 6, '940': 6, '101': 6, '624': 6, '900': 6, '446': 6, '1176': 6, '791': 6, '1314': 6, '210': 5, '348': 5, '871': 5, '1394': 5, '417': 5, '1009': 5, '32': 5, '762': 5, '831': 5, '1423': 5, '61': 5, '584': 5, '199': 5, '722': 5, '1245': 5, '268': 5, '1078': 4, '170': 4, '1354': 4, '377': 4, '515': 4})

# %%
length_per_trait = list(count_of_traits_per_NFT.values())
print(length_per_trait)
# Out:
# [5, 7, 7, 6, 9, 6, 5, 5, 5, 5, 6, 8, 8, 5, 5, 7, 4, 6, 6, 7, 4, 8, 7, 7, 5, 8, 7, 5, 4, 4, 6, 5, 6, 9, 7, 4, 7, 5, 5, 7, 7, 7, 6, 5, 5, 5, 5, 6, 6, 7]

# %%
#NFT_rarity_score
# Input list initialization
Input = Trait_rarity_score
  
# list of length in which we have to split
length_to_split = length_per_trait
  
# Using islice
Inputt = iter(Input)
NFT_rarity_score = [sum(list(islice(Inputt, elem)))
          for elem in length_to_split]
  
# Printing Output
#print(Input)
#print("Split length list: ", length_to_split)
print(len(NFT_rarity_score))
print(NFT_rarity_score[:5])
# Out:
# 50
# [5.089661739649272, 1.6522857502913788, 3.806742255728938, 0.7841268831946387, 1.4790641477063755]

# %%
data = {'NFT_ID': NFT_ID,
        'NFT_Rarity_Score': NFT_rarity_score
        }

NFT_rarity_df = pd.DataFrame.from_dict(data).sort_values(by='NFT_Rarity_Score', ascending=False)
NFT_rarity_df.head()
# Out:
#    NFT_ID  NFT_Rarity_Score
# 0     210          5.089662
# 29    377          3.989950
# 17    101          3.979075
# 2    1256          3.806742
# 43    199          3.530149

# %%
# Creating a new column with a rank
NFT_rarity_df['NFT_Ranking_Position'] = df['NFT_Rarity_Score'].rank(ascending=False)

# %%
NFTs_ranked = NFT_rarity_df.set_index('NFT_ID')
NFTs_ranked.head()
# Out:
#         NFT_Rarity_Score  NFT_Ranking_Position
# NFT_ID
# 210             5.089662                   1.0
# 377             3.989950                   2.0
# 101             3.979075                   3.0
# 1256            3.806742                   4.0
# 199             3.530149                   5.0

# %%
#Export data to JSON
df.to_json(r'/Users/renesalmon/code/reneSalmon/NFT_Rarity_Scoring_API/NFT_ranking.json', orient='records')
f = open('/Users/renesalmon/code/reneSalmon/NFT_Rarity_Scoring_API/NFT_ranking.json')
data = json.load(f)
data
# Out:
# [{'NFT_ID': '210',
#   'NFT_Rarity_Score': 5.0896617396,
#   'NFT_Ranking_Position': 1.0},
#  {'NFT_ID': '377',
#   'NFT_Rarity_Score': 3.9899497628,
#   'NFT_Ranking_Position': 2.0},
#  {'NFT_ID': '101',
#   'NFT_Rarity_Score': 3.9790748352,
#   'NFT_Ranking_Position': 3.0},
#  {'NFT_ID': '1256',
#   'NFT_Rarity_Score': 3.8067422557,
#   'NFT_Ranking_Position': 4.0},
#  {'NFT_ID': '199',
#   'NFT_Rarity_Score': 3.5301491296,
#   'NFT_Ranking_Position': 5.0},
#  {'NFT_ID': '900',
#   'NFT_Rarity_Score': 3.1227977205,
#   'NFT_Ranking_Position': 6.0},
#  {'NFT_ID': '417',
#   'NFT_Rarity_Score': 3.1121162036,
#   'NFT_Ranking_Position': 7.0},
#  {'NFT_ID': '969',
#   'NFT_Rarity_Score': 2.1469654561,
#   'NFT_Ranking_Position': 8.0},
#  {'NFT_ID': '871',
#   'NFT_Rarity_Score': 2.0026196817,
#   'NFT_Ranking_Position': 9.0},
#  {'NFT_ID': '762',
#   'NFT_Rarity_Score': 1.9974288832,
#   'NFT_Ranking_Position': 10.0},
#  {'NFT_ID': '1009',
#   'NFT_Rarity_Score': 1.9329312314,
#   'NFT_Ranking_Position': 11.0},
#  {'NFT_ID': '1354',
#   'NFT_Rarity_Score': 1.9145857739,
#   'NFT_Ranking_Position': 12.0},
#  {'NFT_ID': '1147',
#   'NFT_Rarity_Score': 1.8732208304,
#   'NFT_Ranking_Position': 13.0},
#  {'NFT_ID': '446',
#   'NFT_Rarity_Score': 1.8573091575,
#   'NFT_Ranking_Position': 14.0},
#  {'NFT_ID': '733',
#   'NFT_Rarity_Score': 1.6522857503,
#   'NFT_Ranking_Position': 15.0},
#  {'NFT_ID': '1423',
#   'NFT_Rarity_Score': 1.5945304831,
#   'NFT_Ranking_Position': 16.0},
#  {'NFT_ID': '1078',
#   'NFT_Rarity_Score': 1.5090934763,
#   'NFT_Ranking_Position': 17.0},
#  {'NFT_ID': '584',
#   'NFT_Rarity_Score': 1.4914494516,
#   'NFT_Ranking_Position': 18.0},
#  {'NFT_ID': '32',
#   'NFT_Rarity_Score': 1.4887291937,
#   'NFT_Ranking_Position': 19.0},
#  {'NFT_ID': '802',
#   'NFT_Rarity_Score': 1.4790641477,
#   'NFT_Ranking_Position': 20.0},
#  {'NFT_ID': '170',
#   'NFT_Rarity_Score': 1.4658281349,
#   'NFT_Ranking_Position': 21.0},
#  {'NFT_ID': '348',
#   'NFT_Rarity_Score': 1.4507773249,
#   'NFT_Ranking_Position': 22.0},
#  {'NFT_ID': '693',
#   'NFT_Rarity_Score': 1.4400766866,
#   'NFT_Ranking_Position': 23.0},
#  {'NFT_ID': '1492',
#   'NFT_Rarity_Score': 1.3795267837,
#   'NFT_Ranking_Position': 24.0},
#  {'NFT_ID': '337',
#   'NFT_Rarity_Score': 1.2341966654,
#   'NFT_Ranking_Position': 25.0},
#  {'NFT_ID': '624',
#   'NFT_Rarity_Score': 1.2252418469,
#   'NFT_Ranking_Position': 26.0},
#  {'NFT_ID': '1463',
#   'NFT_Rarity_Score': 1.2174959339,
#   'NFT_Ranking_Position': 27.0},
#  {'NFT_ID': '130',
#   'NFT_Rarity_Score': 1.1966822191,
#   'NFT_Ranking_Position': 28.0},
#  {'NFT_ID': '1038',
#   'NFT_Rarity_Score': 1.180278167,
#   'NFT_Ranking_Position': 29.0},
#  {'NFT_ID': '1216',
#   'NFT_Rarity_Score': 1.1655940605,
#   'NFT_Ranking_Position': 30.0},
#  {'NFT_ID': '653',
#   'NFT_Rarity_Score': 1.1585772818,
#   'NFT_Ranking_Position': 31.0},
#  {'NFT_ID': '486',
#   'NFT_Rarity_Score': 1.1296076829,
#   'NFT_Ranking_Position': 32.0},
#  {'NFT_ID': '1176',
#   'NFT_Rarity_Score': 1.1263230879,
#   'NFT_Ranking_Position': 33.0},
#  {'NFT_ID': '1107',
#   'NFT_Rarity_Score': 1.1154247484,
#   'NFT_Ranking_Position': 34.0},
#  {'NFT_ID': '1245',
#   'NFT_Rarity_Score': 1.0517297681,
#   'NFT_Ranking_Position': 35.0},
#  {'NFT_ID': '831',
#   'NFT_Rarity_Score': 1.0077272136,
#   'NFT_Ranking_Position': 36.0},
#  {'NFT_ID': '268',
#   'NFT_Rarity_Score': 1.005080286,
#   'NFT_Ranking_Position': 37.0},
#  {'NFT_ID': '515',
#   'NFT_Rarity_Score': 0.9916891414,
#   'NFT_Ranking_Position': 38.0},
#  {'NFT_ID': '555',
#   'NFT_Rarity_Score': 0.9177287331,
#   'NFT_Ranking_Position': 39.0},
#  {'NFT_ID': '940',
#   'NFT_Rarity_Score': 0.9070871482,
#   'NFT_Ranking_Position': 40.0},
#  {'NFT_ID': '791',
#   'NFT_Rarity_Score': 0.8947466448,
#   'NFT_Ranking_Position': 41.0},
#  {'NFT_ID': '1325',
#   'NFT_Rarity_Score': 0.8393653598,
#   'NFT_Ranking_Position': 42.0},
#  {'NFT_ID': '1285',
#   'NFT_Rarity_Score': 0.8167402789,
#   'NFT_Ranking_Position': 43.0},
#  {'NFT_ID': '61',
#   'NFT_Rarity_Score': 0.8157842124,
#   'NFT_Ranking_Position': 44.0},
#  {'NFT_ID': '279',
#   'NFT_Rarity_Score': 0.7841268832,
#   'NFT_Ranking_Position': 45.0},
#  {'NFT_ID': '722',
#   'NFT_Rarity_Score': 0.7534222347,
#   'NFT_Ranking_Position': 46.0},
#  {'NFT_ID': '1394',
#   'NFT_Rarity_Score': 0.7029045809,
#   'NFT_Ranking_Position': 47.0},
#  {'NFT_ID': '308',
#   'NFT_Rarity_Score': 0.6784397118,
#   'NFT_Ranking_Position': 48.0},
#  {'NFT_ID': '239',
#   'NFT_Rarity_Score': 0.6727177657,
#   'NFT_Ranking_Position': 49.0},
#  {'NFT_ID': '1314',
#   'NFT_Rarity_Score': 0.590075109,
#   'NFT_Ranking_Position': 50.0}]
